# %%
import matplotlib.pyplot as plt
import networkx as nx
import topologies.Equality as Equality

# %%
eq=Equality.Equalitytopo(14, 6, [-1,1,3,9], [4])

# %%
# Draw the graph
pos = nx.shell_layout(eq.nx_graph)
nx.draw(eq.nx_graph, pos, with_labels=True, node_color='lightblue', node_size=50)
plt.title("Random Regular Directed Graph")
plt.show()

# %%
eq.calculate_diameter()
# Out:
# 2
