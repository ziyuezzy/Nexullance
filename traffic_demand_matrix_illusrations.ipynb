# %%
import globals as gl
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 20})

# %%
V = 8
D = 2

# %%
# show the 2D array as a heatmap
plt.imshow(gl.generate_uniform_traffic_pattern(V, D))
# plt.colorbar(label='relative flow intensity')
plt.xlabel('source router id')
plt.ylabel('destination router id')
plt.title('uniform')
plt.show()

# %%
# show the 2D array as a heatmap
plt.imshow(gl.generate_diagonal_traffic_pattern(V, D, 1))
# plt.colorbar(label='relative flow intensity')
plt.xlabel('source router id')
plt.ylabel('destination router id')
plt.title('nearst-neighbour')
plt.show()

# %%
# show the 2D array as a heatmap
plt.imshow(gl.generate_shift_traffic_pattern(V, D, 1))
plt.colorbar(label='relative flow intensity')
plt.xlabel('source router id')
plt.ylabel('destination router id')
plt.title('shift-1')
plt.show()

# %%
# show the 2D array as a heatmap
plt.imshow(gl.generate_half_shift_traffic_pattern(V, D))
# plt.colorbar(label='relative flow intensity')
plt.xlabel('source router id')
plt.ylabel('destination router id')
plt.title('shift-half')
plt.show()

# %%
# show the 2D array as a heatmap
plt.imshow(gl.generate_uniform_cluster_pattern(V, D, 2))
# plt.colorbar(label='relative flow intensity')
plt.xlabel('source router id')
plt.ylabel('destination router id')
plt.title('router-clustered')
plt.show()

# %%
# show the 2D array as a heatmap
plt.imshow(gl.generate_random_permutation_pattern(V, D, 0))
plt.colorbar(label='relative flow intensity')
plt.xlabel('source router id')
plt.ylabel('destination router id')
plt.title('random-permutation')
plt.show()
