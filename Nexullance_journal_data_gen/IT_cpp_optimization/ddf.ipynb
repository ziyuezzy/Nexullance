# %%
import pandas as pd
import os
ref_data = pd.read_csv(os.path.join("/users/ziyzhang/topology-research/Nexullance_journal_data_gen/IT_cpp_compare/Nexullance_MP_APST4/DDF.csv"))
# ref_data = pd.read_csv(os.path.join("/users/ziyzhang/topology-research/Nexullance_journal_data_gen/IT_cpp_compare/Nexullance_OPT/DDF.csv"))

# %%
import sys
sys.path.append("/users/ziyzhang/topology-research/")
from topologies.DDF import DDFtopo
import globals as gl
import numpy as np
# add the path to the Nexullance_IT c++ library
sys.path.append("/users/ziyzhang/topology-research/nexullance/IT_boost/build")
from Nexullance_IT_cpp import Nexullance_IT_interface

# %%
Cap_remote = 10 #GBps
Cap_local = 10 #GBps

# %%
def difference_against_opt(alpha, beta):

    sum_difference = 0

    configs = gl.ddf_configs[:1]
    
    for V, D in configs:
        EPR = (D+1)//2
        _network = DDFtopo(V, D)
        arcs = _network.generate_graph_arcs()
        ASP, _ = _network.calculate_all_shortest_paths()
        ECMP_ASP = gl.ECMP(ASP)

        def run_for_traffic_pattern(_arcs, _traffic_pattern, _M_EPs, _alpha, _beta):
            remote_link_flows, local_link_flows = _network.distribute_M_EPs_on_weighted_paths(ECMP_ASP, EPR, _M_EPs)
            max_remote_link_load = np.max(remote_link_flows)/Cap_remote
            max_local_link_load = np.max(local_link_flows)/Cap_local
            # adapt the traffic scaling factor to 10x saturation
            traffic_scaling = 10.0/max(max_local_link_load, max_remote_link_load)
            _M_EPs = traffic_scaling * _M_EPs
            remote_link_flows, local_link_flows = _network.distribute_M_EPs_on_weighted_paths(ECMP_ASP, EPR, _M_EPs)
            max_remote_link_load = np.max(remote_link_flows)/Cap_remote
            max_local_link_load = np.max(local_link_flows)/Cap_local
            # run Nexullance_IT
            nexu_it = Nexullance_IT_interface(V, _arcs, gl.convert_M_EPs_to_M_R(_M_EPs, V, EPR), False)
            nexu_it.set_parameters(_alpha, _beta)
            nexu_it.run()
            Lremote_NEXU = nexu_it.get_max_link_load()
            Phi = gl.network_total_throughput(_M_EPs, Lremote_NEXU, max_local_link_load)
            return Phi/(V*EPR)

        traffic_pattern = "uniform"
        M_EPs = gl.generate_uniform_traffic_pattern(V, EPR)
        difference = (ref_data[(ref_data["traffic"]==traffic_pattern) & (ref_data["V"]==V)]["Phi_per_EP"].values[0] - run_for_traffic_pattern(arcs, traffic_pattern, M_EPs, alpha, beta))
        assert difference >= 0, "Difference is negative"
        sum_difference -= difference
        
        traffic_pattern = "nearst-neighbour"
        M_EPs = gl.generate_diagonal_traffic_pattern(V, EPR, 1)
        difference = (ref_data[(ref_data["traffic"]==traffic_pattern) & (ref_data["V"]==V)]["Phi_per_EP"].values[0] - run_for_traffic_pattern(arcs, traffic_pattern, M_EPs, alpha, beta))
        assert difference >= 0, "Difference is negative"
        sum_difference -= difference

        traffic_pattern = "shift_1"
        M_EPs = gl.generate_shift_traffic_pattern(V, EPR, 1)
        difference = (ref_data[(ref_data["traffic"]==traffic_pattern) & (ref_data["V"]==V)]["Phi_per_EP"].values[0] - run_for_traffic_pattern(arcs, traffic_pattern, M_EPs, alpha, beta))
        assert difference >= 0, "Difference is negative"
        sum_difference -= difference

        traffic_pattern = "shift_half"
        M_EPs = gl.generate_half_shift_traffic_pattern(V, EPR)
        difference = (ref_data[(ref_data["traffic"]==traffic_pattern) & (ref_data["V"]==V)]["Phi_per_EP"].values[0] - run_for_traffic_pattern(arcs, traffic_pattern, M_EPs, alpha, beta))
        assert difference >= 0, "Difference is negative"
        sum_difference -= difference

        traffic_pattern = "router-cluster"
        M_EPs = gl.generate_uniform_cluster_pattern(V, EPR, 4) # four clusters
        difference = (ref_data[(ref_data["traffic"]==traffic_pattern) & (ref_data["V"]==V)]["Phi_per_EP"].values[0] - run_for_traffic_pattern(arcs, traffic_pattern, M_EPs, alpha, beta))
        assert difference >= 0, "Difference is negative"
        sum_difference -= difference
                
        traffic_pattern = "random-permute"
        M_EPs = gl.generate_random_permutation_pattern(V, EPR, 0)
        difference = (ref_data[(ref_data["traffic"]==traffic_pattern) & (ref_data["V"]==V)]["Phi_per_EP"].values[0] - run_for_traffic_pattern(arcs, traffic_pattern, M_EPs, alpha, beta))
        assert difference >= 0, "Difference is negative"
        sum_difference -= difference

    return sum_difference

# %%
from bayes_opt import BayesianOptimization
# Bounded region of parameter space
pbounds = {'alpha': (0.1, 10.0), 'beta': (0.0, 10.0)}
optimizer = BayesianOptimization(
    f=difference_against_opt,
    pbounds=pbounds,
    random_state=1,
)
optimizer.probe(
    params=[0.1, 7.0],
    lazy=True,
)
optimizer.probe(
    params=[1.0, 0.1],
    lazy=True,
)
# Out:
# /users/ziyzhang/miniconda3/envs/gt/lib/python3.12/site-packages/numpy/core/getlimits.py:549: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /users/ziyzhang/miniconda3/envs/gt/lib/python3.12/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /users/ziyzhang/miniconda3/envs/gt/lib/python3.12/site-packages/numpy/core/getlimits.py:549: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /users/ziyzhang/miniconda3/envs/gt/lib/python3.12/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)

# %%
optimizer.maximize(
    init_points=10,
    n_iter=100,
)
# Out:
# |   iter    |  target   |   alpha   |   beta    |
# -------------------------------------------------
# | 1         | -3.036    | 0.1       | 7.0       |
# step 2: no progress, terminating after22 attempts
# step 2: no progress, terminating after2 attempts
# step 2: no progress, terminating after38 attempts
# step 2: no progress, terminating after25 attempts
# | 2         | -7.501    | 1.0       | 0.1       |
# | 3         | -3.11     | 4.229     | 7.203     |
# step 2: no progress, terminating after6 attempts
# | 4         | -3.206    | 0.1011    | 3.023     |
# step 2: no progress, terminating after28 attempts
# step 2: no progress, terminating after14 attempts
# | 5         | -5.011    | 1.553     | 0.9234    |
# step 2: no progress, terminating after2 attempts
# | 6         | -3.402    | 1.944     | 3.456     |
# step 2: no progress, terminating after12 attempts
# | 7         | -3.021    | 4.028     | 5.388     |
# | 8         | -2.929    | 4.25      | 6.852     |
# step 2: no progress, terminating after35 attempts
# | 9         | -3.142    | 2.124     | 8.781     |
# step 2: no progress, terminating after31 attempts
# | 10        | -3.06     | 0.3711    | 6.705     |
# step 2: no progress, terminating after12 attempts
# | 11        | -3.143    | 4.231     | 5.587     |
# step 2: no progress, terminating after34 attempts
# | 12        | -3.184    | 1.49      | 1.981     |
# step 2: no progress, terminating after31 attempts
# | 13        | -3.41     | 4.699     | 2.297     |
# | 14        | -3.017    | 0.119     | 9.849     |
# step 2: no progress, terminating after23 attempts
# step 2: no progress, terminating after21 attempts
# step 2: no progress, terminating after29 attempts
# step 2: no progress, terminating after36 attempts
# | 15        | -5.847    | 8.969     | 1.028     |
# | 16        | -2.946    | 10.0      | 10.0      |
# | 17        | -2.98     | 8.431     | 7.942     |
# | 18        | -2.934    | 7.291     | 10.0      |
# | 19        | -3.042    | 10.0      | 6.083     |
# | 20        | -3.051    | 7.504     | 5.685     |
# | 21        | -3.017    | 4.887     | 9.962     |
# | 22        | -2.981    | 6.417     | 7.87      |
# | 23        | -2.957    | 2.467     | 6.332     |
# | 24        | -3.0      | 10.0      | 8.117     |
# step 2: no progress, terminating after12 attempts
# step 2: no progress, terminating after14 attempts
# | 25        | -6.841    | 5.148     | 0.0       |
# step 2: no progress, terminating after8 attempts
# | 26        | -3.297    | 6.092     | 3.856     |
# | 27        | -2.97     | 10.0      | 4.111     |
# | 28        | -2.97     | 2.648     | 9.971     |
# | 29        | -3.176    | 3.939     | 3.546     |
# step 2: no progress, terminating after29 attempts
# | 30        | -3.424    | 0.1       | 4.913     |
# step 2: no progress, terminating after11 attempts
# | 31        | -3.061    | 8.417     | 4.321     |
# | 32        | -3.017    | 8.679     | 9.956     |
# | 33        | -3.047    | 0.5073    | 8.511     |
# | 34        | -2.97     | 1.212     | 9.984     |
# step 2: no progress, terminating after15 attempts
# | 35        | -3.358    | 2.938     | 2.189     |
# step 2: no progress, terminating after18 attempts
# | 36        | -3.026    | 8.684     | 6.283     |
# | 37        | -2.956    | 6.202     | 9.293     |
# | 38        | -2.985    | 7.523     | 8.816     |
# step 2: no progress, terminating after8 attempts
# | 39        | -3.26     | 2.716     | 5.147     |
# step 2: no progress, terminating after35 attempts
# | 40        | -3.193    | 9.326     | 5.023     |
# | 41        | -3.064    | 7.376     | 6.986     |
# step 2: no progress, terminating after14 attempts
# | 42        | -3.176    | 1.572     | 7.421     |
# | 43        | -3.07     | 3.402     | 6.416     |
# | 44        | -2.948    | 5.716     | 6.654     |
# | 45        | -2.982    | 9.35      | 8.959     |
# | 46        | -2.934    | 6.067     | 9.985     |
# | 47        | -2.97     | 3.727     | 10.0      |
# | 48        | -3.076    | 9.44      | 7.196     |
# | 49        | -2.926    | 5.407     | 7.639     |
# step 2: no progress, terminating after32 attempts
# | 50        | -2.896    | 7.298     | 4.428     |
# step 2: no progress, terminating after26 attempts
# | 51        | -3.268    | 7.448     | 3.418     |
# step 2: no progress, terminating after1 attempts
# | 52        | -3.24     | 1.472     | 5.986     |
# step 2: no progress, terminating after34 attempts
# step 2: no progress, terminating after24 attempts
# | 53        | -3.348    | 9.997     | 3.141     |
# | 54        | -3.2      | 6.465     | 5.235     |
# step 2: no progress, terminating after12 attempts
# | 55        | -2.982    | 4.967     | 8.931     |
# step 2: no progress, terminating after20 attempts
# | 56        | -3.14     | 3.478     | 9.13      |
# | 57        | -3.009    | 9.979     | 9.2       |
# step 2: no progress, terminating after36 attempts
# | 58        | -2.906    | 5.036     | 6.89      |
# | 59        | -2.932    | 4.409     | 4.453     |
# step 2: no progress, terminating after15 attempts
# | 60        | -3.183    | 1.069     | 2.831     |
# step 2: no progress, terminating after23 attempts
# | 61        | -3.206    | 3.704     | 4.578     |
# step 2: no progress, terminating after33 attempts
# | 62        | -3.114    | 4.905     | 3.465     |
# step 2: no progress, terminating after20 attempts
# | 63        | -3.083    | 8.352     | 9.073     |
# | 64        | -2.996    | 1.017     | 9.274     |
# | 65        | -3.053    | 5.724     | 8.484     |
# | 66        | -2.934    | 0.1       | 9.03      |
# | 67        | -3.049    | 7.878     | 4.858     |
# | 68        | -3.094    | 6.313     | 7.117     |
# | 69        | -2.886    | 7.447     | 7.957     |
# | 70        | -3.239    | 8.258     | 7.091     |
# step 2: no progress, terminating after5 attempts
# | 71        | -3.102    | 9.223     | 3.78      |
# | 72        | -2.951    | 1.889     | 9.701     |
# | 73        | -2.916    | 6.705     | 9.978     |
# step 2: no progress, terminating after11 attempts
# | 74        | -3.047    | 6.856     | 8.506     |
# | 75        | -2.922    | 9.455     | 9.998     |
# step 2: no progress, terminating after2 attempts
# | 76        | -3.113    | 5.122     | 4.61      |
# | 77        | -2.859    | 9.984     | 6.86      |
# | 78        | -2.972    | 0.1       | 7.962     |
# | 79        | -3.016    | 2.587     | 7.172     |
# | 80        | -3.018    | 9.992     | 7.36      |
# step 2: no progress, terminating after0 attempts
# | 81        | -3.101    | 5.452     | 9.445     |
# step 2: no progress, terminating after16 attempts
# | 82        | -3.009    | 4.322     | 9.421     |
# step 2: no progress, terminating after7 attempts
# | 83        | -2.92     | 1.989     | 2.452     |
# step 2: no progress, terminating after31 attempts
# | 84        | -3.073    | 9.428     | 6.348     |
# step 2: no progress, terminating after2 attempts
# | 85        | -3.019    | 9.176     | 8.268     |
# | 86        | -2.875    | 7.934     | 8.271     |
# step 2: no progress, terminating after36 attempts
# | 87        | -3.126    | 0.1       | 6.08      |
# | 88        | -2.915    | 6.947     | 9.478     |
# step 2: no progress, terminating after2 attempts
# | 89        | -3.017    | 7.677     | 4.117     |
# step 2: no progress, terminating after8 attempts
# | 90        | -3.081    | 8.377     | 5.677     |
# step 2: no progress, terminating after18 attempts
# | 91        | -3.11     | 4.78      | 8.307     |
# | 92        | -3.016    | 5.498     | 7.149     |
# | 93        | -3.048    | 5.349     | 6.162     |
# | 94        | -3.08     | 6.535     | 6.224     |
# step 2: no progress, terminating after26 attempts
# | 95        | -3.062    | 2.038     | 6.741     |
# | 96        | -2.834    | 4.642     | 6.593     |
# step 2: no progress, terminating after6 attempts
# | 97        | -3.146    | 3.266     | 5.686     |
# step 2: no progress, terminating after6 attempts
# | 98        | -3.098    | 6.897     | 4.249     |
# | 99        | -3.092    | 7.197     | 4.891     |
# step 2: no progress, terminating after14 attempts
# | 100       | -3.198    | 5.909     | 2.747     |
# step 2: no progress, terminating after13 attempts
# | 101       | -2.955    | 9.992     | 4.827     |
# | 102       | -3.08     | 7.86      | 6.229     |
# | 103       | -2.97     | 7.939     | 9.988     |
# | 104       | -3.017    | 1.834     | 9.988     |
# | 105       | -2.962    | 2.669     | 9.441     |
# | 106       | -2.951    | 0.6592    | 9.686     |
# step 2: no progress, terminating after32 attempts
# | 107       | -2.926    | 7.021     | 7.668     |
# step 2: no progress, terminating after2 attempts
# | 108       | -3.187    | 4.434     | 4.889     |
# step 2: no progress, terminating after27 attempts
# | 109       | -3.242    | 4.626     | 4.05      |
# step 2: no progress, terminating after1 attempts
# | 110       | -3.206    | 5.211     | 2.927     |
# step 2: no progress, terminating after24 attempts
# | 111       | -2.969    | 1.295     | 4.716     |
# step 2: no progress, terminating after18 attempts
# | 112       | -3.19     | 0.7788    | 4.02      |
# =================================================

# %%
optimizer.max
# Out:
# {'target': -2.8341131070711123,
#  'params': {'alpha': 4.6419767269134455, 'beta': 6.593203706205871}}
