# %%
import pandas as pd
import os
ref_data = pd.read_csv(os.path.join("/users/ziyzhang/topology-research/Nexullance_journal_data_gen/IT_cpp_compare/Nexullance_MP_APST4/Slimfly.csv"))
# ref_data = pd.read_csv(os.path.join("/users/ziyzhang/topology-research/Nexullance_journal_data_gen/IT_cpp_compare/Nexullance_OPT/DDF.csv"))

# %%
import sys
sys.path.append("/users/ziyzhang/topology-research/")
from topologies.Slimfly import Slimflytopo
import globals as gl
import numpy as np
# add the path to the Nexullance_IT c++ library
sys.path.append("/users/ziyzhang/topology-research/nexullance/IT_boost/build")
from Nexullance_IT_cpp import Nexullance_IT_interface

# %%
Cap_remote = 10 #GBps
Cap_local = 10 #GBps

# %%
def difference_against_opt(alpha, beta):

    sum_difference = 0

    configs = gl.sf_configs[:1]
    
    for V, D in configs:
        EPR = (D+1)//2
        _network = Slimflytopo(V, D)
        arcs = _network.generate_graph_arcs()
        ASP, _ = _network.calculate_all_shortest_paths()
        ECMP_ASP = gl.ECMP(ASP)

        def run_for_traffic_pattern(_arcs, _traffic_pattern, _M_EPs, _alpha, _beta):
            remote_link_flows, local_link_flows = _network.distribute_M_EPs_on_weighted_paths(ECMP_ASP, EPR, _M_EPs)
            max_remote_link_load = np.max(remote_link_flows)/Cap_remote
            max_local_link_load = np.max(local_link_flows)/Cap_local
            # adapt the traffic scaling factor to 10x saturation
            traffic_scaling = 10.0/max(max_local_link_load, max_remote_link_load)
            _M_EPs = traffic_scaling * _M_EPs
            remote_link_flows, local_link_flows = _network.distribute_M_EPs_on_weighted_paths(ECMP_ASP, EPR, _M_EPs)
            max_remote_link_load = np.max(remote_link_flows)/Cap_remote
            max_local_link_load = np.max(local_link_flows)/Cap_local
            # run Nexullance_IT
            nexu_it = Nexullance_IT_interface(V, _arcs, gl.convert_M_EPs_to_M_R(_M_EPs, V, EPR), False)
            nexu_it.set_parameters(_alpha, _beta)
            nexu_it.run()
            Lremote_NEXU = nexu_it.get_max_link_load()
            Phi = gl.network_total_throughput(_M_EPs, Lremote_NEXU, max_local_link_load)
            return Phi/(V*EPR)

        traffic_pattern = "uniform"
        M_EPs = gl.generate_uniform_traffic_pattern(V, EPR)
        difference = (ref_data[(ref_data["traffic"]==traffic_pattern) & (ref_data["V"]==V)]["Phi_per_EP"].values[0] - run_for_traffic_pattern(arcs, traffic_pattern, M_EPs, alpha, beta))
        assert difference >= 0, "Difference is negative"
        sum_difference -= difference
        
        traffic_pattern = "nearst-neighbour"
        M_EPs = gl.generate_diagonal_traffic_pattern(V, EPR, 1)
        difference = (ref_data[(ref_data["traffic"]==traffic_pattern) & (ref_data["V"]==V)]["Phi_per_EP"].values[0] - run_for_traffic_pattern(arcs, traffic_pattern, M_EPs, alpha, beta))
        assert difference >= 0, "Difference is negative"
        sum_difference -= difference

        traffic_pattern = "shift_1"
        M_EPs = gl.generate_shift_traffic_pattern(V, EPR, 1)
        difference = (ref_data[(ref_data["traffic"]==traffic_pattern) & (ref_data["V"]==V)]["Phi_per_EP"].values[0] - run_for_traffic_pattern(arcs, traffic_pattern, M_EPs, alpha, beta))
        assert difference >= 0, "Difference is negative"
        sum_difference -= difference

        traffic_pattern = "shift_half"
        M_EPs = gl.generate_half_shift_traffic_pattern(V, EPR)
        difference = (ref_data[(ref_data["traffic"]==traffic_pattern) & (ref_data["V"]==V)]["Phi_per_EP"].values[0] - run_for_traffic_pattern(arcs, traffic_pattern, M_EPs, alpha, beta))
        assert difference >= 0, "Difference is negative"
        sum_difference -= difference

        traffic_pattern = "router-cluster"
        M_EPs = gl.generate_uniform_cluster_pattern(V, EPR, 4) # four clusters
        difference = (ref_data[(ref_data["traffic"]==traffic_pattern) & (ref_data["V"]==V)]["Phi_per_EP"].values[0] - run_for_traffic_pattern(arcs, traffic_pattern, M_EPs, alpha, beta))
        assert difference >= 0, "Difference is negative"
        sum_difference -= difference
                
        traffic_pattern = "random-permute"
        M_EPs = gl.generate_random_permutation_pattern(V, EPR, 0)
        difference = (ref_data[(ref_data["traffic"]==traffic_pattern) & (ref_data["V"]==V)]["Phi_per_EP"].values[0] - run_for_traffic_pattern(arcs, traffic_pattern, M_EPs, alpha, beta))
        assert difference >= 0, "Difference is negative"
        sum_difference -= difference

    return sum_difference

# %%
from bayes_opt import BayesianOptimization
# Bounded region of parameter space
pbounds = {'alpha': (0.1, 10.0), 'beta': (0.0, 10.0)}
optimizer = BayesianOptimization(
    f=difference_against_opt,
    pbounds=pbounds,
    random_state=1,
)
optimizer.probe(
    params=[0.1, 7.0],
    lazy=True,
)
optimizer.probe(
    params=[1.0, 0.1],
    lazy=True,
)

# %%
optimizer.maximize(
    init_points=10,
    n_iter=100,
)
# Out:
# |   iter    |  target   |   alpha   |   beta    |
# -------------------------------------------------
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 1         | -2.595    | 0.1       | 7.0       |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after11 attempts
# step 2: no progress, terminating after1 attempts
# step 2: no progress, terminating after11 attempts
# | 2         | -5.172    | 1.0       | 0.1       |
# step 2: no progress, terminating after8 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after2 attempts
# step 2: no progress, terminating after20 attempts
# | 3         | -2.595    | 4.229     | 7.203     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# step 2: no progress, terminating after18 attempts
# | 4         | -2.85     | 0.1011    | 3.023     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# step 2: no progress, terminating after1 attempts
# step 2: no progress, terminating after28 attempts
# | 5         | -3.888    | 1.553     | 0.9234    |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# step 2: no progress, terminating after18 attempts
# | 6         | -2.616    | 1.944     | 3.456     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after2 attempts
# step 2: no progress, terminating after20 attempts
# | 7         | -2.416    | 4.028     | 5.388     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after2 attempts
# step 2: no progress, terminating after20 attempts
# | 8         | -2.595    | 4.25      | 6.852     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# step 2: no progress, terminating after2 attempts
# | 9         | -2.87     | 2.124     | 8.781     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 10        | -2.528    | 0.3711    | 6.705     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after2 attempts
# step 2: no progress, terminating after20 attempts
# | 11        | -2.66     | 4.231     | 5.587     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# step 2: no progress, terminating after15 attempts
# | 12        | -3.032    | 1.49      | 1.981     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# step 2: no progress, terminating after2 attempts
# | 13        | -2.595    | 2.382     | 5.707     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 14        | -2.66     | 4.151     | 3.393     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 15        | -2.66     | 6.801     | 9.999     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 16        | -2.66     | 9.649     | 10.0      |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 17        | -2.66     | 8.378     | 7.666     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 18        | -2.416    | 10.0      | 5.331     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 19        | -2.66     | 10.0      | 3.186     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 20        | -2.66     | 8.078     | 4.795     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after6 attempts
# step 2: no progress, terminating after18 attempts
# step 2: no progress, terminating after16 attempts
# step 2: no progress, terminating after4 attempts
# | 21        | -3.888    | 7.693     | 1.236     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 22        | -2.595    | 10.0      | 7.217     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 23        | -2.745    | 4.558     | 9.885     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 24        | -0.6598   | 0.1       | 10.0      |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 25        | -0.8221   | 0.1       | 9.315     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 26        | -2.66     | 0.6982    | 9.955     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 27        | -0.8753   | 0.1023    | 9.728     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 28        | -0.6164   | 0.111     | 8.722     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 29        | -2.745    | 0.6409    | 8.319     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 30        | -1.0      | 0.2538    | 8.968     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after18 attempts
# step 2: no progress, terminating after1 attempts
# step 2: no progress, terminating after10 attempts
# | 31        | -5.172    | 4.687     | 0.0       |
# step 2: no progress, terminating after4 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 32        | -2.627    | 6.297     | 7.508     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 33        | -2.528    | 0.1       | 5.027     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after17 attempts
# step 2: no progress, terminating after18 attempts
# step 2: no progress, terminating after6 attempts
# step 2: no progress, terminating after6 attempts
# | 34        | -5.172    | 10.0      | 0.0       |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 35        | -2.528    | 6.118     | 4.101     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 36        | -2.595    | 6.691     | 5.851     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 37        | -2.692    | 8.206     | 9.296     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 38        | -2.66     | 3.114     | 4.412     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 39        | -2.66     | 8.67      | 6.175     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after4 attempts
# step 2: no progress, terminating after20 attempts
# | 40        | -2.595    | 2.789     | 7.224     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 41        | -2.616    | 9.981     | 8.642     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 42        | -0.7027   | 0.11      | 9.053     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 43        | -2.911    | 7.661     | 3.277     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after2 attempts
# step 2: no progress, terminating after20 attempts
# | 44        | -2.87     | 3.544     | 8.789     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 45        | -1.0      | 0.1       | 8.838     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 46        | -2.562    | 8.963     | 4.704     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 47        | -0.8753   | 0.119     | 8.328     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 48        | -3.032    | 0.3762    | 1.382     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 49        | -0.6598   | 0.1308    | 9.979     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 50        | -2.745    | 8.835     | 8.403     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 51        | -2.528    | 0.3529    | 6.711     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 52        | -2.573    | 0.7201    | 5.274     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 53        | -0.692    | 0.5371    | 9.346     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# step 2: no progress, terminating after5 attempts
# | 54        | -3.032    | 7.299     | 2.415     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 55        | -2.616    | 7.54      | 8.588     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 56        | -2.703    | 0.8542    | 9.174     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 57        | -0.8328   | 0.303     | 9.456     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 58        | -0.7465   | 0.2179    | 8.537     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# step 2: no progress, terminating after12 attempts
# | 59        | -2.393    | 5.359     | 2.241     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 60        | -3.032    | 3.539     | 1.95      |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 61        | -2.605    | 5.628     | 8.768     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 62        | -2.66     | 2.02      | 1.863     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after2 attempts
# step 2: no progress, terminating after20 attempts
# | 63        | -2.681    | 5.666     | 3.279     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# step 2: no progress, terminating after14 attempts
# step 2: no progress, terminating after15 attempts
# | 64        | -3.032    | 7.788     | 1.962     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 65        | -0.8221   | 0.3143    | 9.209     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 66        | -1.0      | 0.2518    | 8.946     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 67        | -0.8328   | 0.1       | 7.819     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after4 attempts
# step 2: no progress, terminating after20 attempts
# | 68        | -2.692    | 2.959     | 9.501     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 69        | -0.7574   | 0.436     | 7.628     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 70        | -2.595    | 0.8954    | 7.434     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# step 2: no progress, terminating after2 attempts
# | 71        | -2.595    | 2.646     | 6.641     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 72        | -0.7574   | 0.1911    | 7.529     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after10 attempts
# step 2: no progress, terminating after20 attempts
# step 2: no progress, terminating after13 attempts
# | 73        | -3.032    | 9.567     | 1.89      |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after10 attempts
# step 2: no progress, terminating after18 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after6 attempts
# | 74        | -5.172    | 6.628     | 0.04441   |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 75        | -2.562    | 5.527     | 5.233     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 76        | -2.595    | 5.412     | 6.596     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 77        | -2.595    | 7.435     | 6.832     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after4 attempts
# step 2: no progress, terminating after1 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after13 attempts
# | 78        | -5.172    | 2.926     | 0.0       |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 79        | -2.66     | 4.607     | 4.472     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# step 2: no progress, terminating after18 attempts
# | 80        | -2.528    | 1.646     | 4.55      |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 81        | -2.562    | 9.955     | 4.255     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 82        | -2.66     | 6.945     | 4.735     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after4 attempts
# step 2: no progress, terminating after20 attempts
# step 2: no progress, terminating after2 attempts
# | 83        | -2.627    | 2.703     | 7.544     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 84        | -2.506    | 8.885     | 3.486     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 85        | -2.66     | 5.699     | 10.0      |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after2 attempts
# step 2: no progress, terminating after20 attempts
# | 86        | -2.416    | 3.595     | 5.428     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 87        | -0.8753   | 0.1213    | 8.348     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 88        | -2.66     | 4.699     | 8.233     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 89        | -2.528    | 0.6657    | 4.061     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 90        | -2.595    | 8.044     | 7.746     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 91        | -2.439    | 6.84      | 5.29      |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 92        | -2.745    | 8.306     | 9.85      |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# step 2: no progress, terminating after4 attempts
# step 2: no progress, terminating after3 attempts
# | 93        | -1.921    | 6.04      | 1.624     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after18 attempts
# | 94        | -3.032    | 5.331     | 1.379     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 95        | -3.032    | 6.233     | 2.288     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 96        | -2.66     | 9.848     | 6.268     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 97        | -2.85     | 2.97      | 3.121     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 98        | -0.8328   | 0.3349    | 7.882     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# step 2: no progress, terminating after18 attempts
# | 99        | -2.66     | 1.44      | 6.2       |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after18 attempts
# step 2: no progress, terminating after10 attempts
# step 2: no progress, terminating after2 attempts
# step 2: no progress, terminating after13 attempts
# | 100       | -5.172    | 6.702     | 0.7131    |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 101       | -2.87     | 6.597     | 8.844     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 102       | -2.595    | 7.674     | 5.784     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# | 103       | -2.439    | 0.9485    | 3.57      |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# step 2: no progress, terminating after13 attempts
# | 104       | -2.461    | 1.329     | 2.374     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after10 attempts
# step 2: no progress, terminating after18 attempts
# step 2: no progress, terminating after6 attempts
# step 2: no progress, terminating after9 attempts
# step 2: no progress, terminating after6 attempts
# | 105       | -5.172    | 8.408     | 0.01845   |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after2 attempts
# step 2: no progress, terminating after20 attempts
# | 106       | -2.528    | 3.683     | 6.78      |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# step 2: no progress, terminating after25 attempts
# | 107       | -2.829    | 4.555     | 2.511     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after3 attempts
# step 2: no progress, terminating after20 attempts
# step 2: no progress, terminating after2 attempts
# | 108       | -2.66     | 2.29      | 9.999     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 109       | -2.627    | 5.338     | 7.558     |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after18 attempts
# step 2: no progress, terminating after20 attempts
# | 110       | -2.911    | 8.693     | 2.58      |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 111       | -2.595    | 9.073     | 7.07      |
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after0 attempts
# step 2: no progress, terminating after20 attempts
# | 112       | -2.573    | 6.843     | 5.287     |
# =================================================

# %%
optimizer.max
# Out:
# {'target': -0.6164028815857314,
#  'params': {'alpha': 0.11096655960689972, 'beta': 8.72157628168244}}
