# %%
import pandas as pd
# import matplotlib.pyplot as plt
import numpy as np
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from plotting_tempelate import plot_scaling_lines
import ast
import matplotlib.pyplot as plt

# %%
raw_data = pd.read_csv('./data_RRG_IT_4+6.csv')

# %%
raw_data['ave_method_1_time'] = raw_data['method1_times[s]'].apply(lambda x: np.average(ast.literal_eval(x)))

# %%
_x_power:int = 1
traffic_pattern = "uniform"
traffic_data = raw_data[raw_data["traffic_pattern"]==traffic_pattern]
_V = list(traffic_data["V"])
traffic_data.keys()
_methods = ["step1", "step2"]
plot_data={}
plot_data["step1"] = list(traffic_data["ave_method_1_time"])
plot_data["step2"] = list(traffic_data["method2_time[s]"])

plot_scaling_lines(_V, plot_data, "scaling of Nexullance_IT two steps "+traffic_pattern, "V^"+ r"$\bf{" + str(_x_power) + "}$", "execution time (s)", False, _x_power)

# %%
_x_power:int = 1
traffic_pattern = "shift_half"
traffic_data = raw_data[raw_data["traffic_pattern"]==traffic_pattern]
_V = list(traffic_data["V"])
traffic_data.keys()
_methods = ["step1", "step2"]
plot_data={}
plot_data["step1"] = list(traffic_data["ave_method_1_time"])
plot_data["step2"] = list(traffic_data["method2_time[s]"])

plot_scaling_lines(_V, plot_data, "scaling of Nexullance_IT two steps "+traffic_pattern, "V^"+ r"$\bf{" + str(_x_power) + "}$", "execution time (s)", False, _x_power)
