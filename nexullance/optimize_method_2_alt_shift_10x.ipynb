# %%
import matplotlib.pyplot as plt
import numpy as np
from Nexullance_IT import Nexullance_IT
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../..')))
from topologies.DDF import DDFtopo
import globals as gl
import copy
from joblib import Parallel, delayed
# %matplotlib widget

# %% [markdown]
# # setup network, not yet using nexullance

# %%
config=(36, 5)
EPR=3
ddf_network = DDFtopo(config[0], config[1])
Cap_remote = 10 #GBps
Cap_local = 10 #GBps
M_EPs = gl.generate_half_shift_traffic_pattern(config[0], EPR) # an numpy matrix filled with ones
scaling_factor = 3
M_EPs = scaling_factor * M_EPs
M_R = gl.convert_M_EPs_to_M_R(M_EPs, config[0], EPR)

# %%
ASP = ddf_network.calculate_all_shortest_paths()
ECMP_ASP = gl.ECMP(ASP)
remote_link_flows, local_link_flows = ddf_network.distribute_M_EPs_on_weighted_paths(ECMP_ASP, EPR, M_EPs)
max_remote_link_load = np.max(remote_link_flows)/Cap_remote
max_local_link_load = np.max(local_link_flows)/Cap_local
print("Max remote link load: ", max_remote_link_load)
print("Max local link load: ", max_local_link_load)
if max_remote_link_load > 1.0 or max_local_link_load > 1.0:
    print("network congestion may present")
    mu = max_local_link_load/max_remote_link_load
    if mu > 1.0:
        print(f"mu = {mu} > 1, max local link load is higher")
    else:
        print(f"mu = {mu} < 1, max remote link load is higher")
else:
    print("network is probably not congested")
print("network_total_throughput = ", gl.network_total_throughput(M_EPs, max_remote_link_load, max_local_link_load), "GBps")
# Out:
# Max remote link load:  1.8
# Max local link load:  0.3
# network congestion may present
# mu = 0.16666666666666666 < 1, max remote link load is higher
# network_total_throughput =  180.0 GBps

# %%
# simply linearly scale everything:
traffic_scaling = 10.0/max(max_local_link_load, max_remote_link_load)
print(f"scaling traffic to:{traffic_scaling}x")
M_EPs = M_EPs*traffic_scaling
M_R = M_R*traffic_scaling

max_remote_link_load = traffic_scaling * max_remote_link_load
max_local_link_load = traffic_scaling * max_local_link_load
print("Max remote link load: ", max_remote_link_load)
print("Max local link load: ", max_local_link_load)
if max_remote_link_load > 1.0 or max_local_link_load > 1.0:
    print("network congestion may present")
    mu = max_local_link_load/max_remote_link_load
    if mu > 1.0:
        print(f"mu = {mu} > 1, max local link load is higher")
    else:
        print(f"mu = {mu} < 1, max remote link load is higher")
else:
    print("network is probably not congested")
print("network_total_throughput = ", gl.network_total_throughput(M_EPs, max_remote_link_load, max_local_link_load), "GBps")
# Out:
# scaling traffic to:5.555555555555555x
# Max remote link load:  10.0
# Max local link load:  1.6666666666666665
# network congestion may present
# mu = 0.16666666666666666 < 1, max remote link load is higher
# network_total_throughput =  179.99999999999997 GBps

# %% [markdown]
# # start to sweep parameters

# %%
# initialize data
_alphas = np.array(list(np.arange(0.0, 10.0, 1.0)), dtype=float)
_betas = np.array(list(np.arange(0.0, 10.0, 1.0)), dtype=float)

num_method_2 = 6
_result_Phis = np.ndarray((num_method_2, len(_alphas), len(_betas)), dtype=float)*0 
# the first dimension corresponds to iterations

# %%
nexu_it = Nexullance_IT(ddf_network.nx_graph, M_R, Cap_remote)

# %%
# Function to be executed in parallel
def parallel_method(alpha, beta):
    nexu_it_test = copy.deepcopy(nexu_it)
    def weighted_method(s: int, d: int, edge_attributes: dict):
        return method_2_weights(s, d, edge_attributes, alpha, beta)
    _, results_list = nexu_it_test.optimize(1, num_method_2, weighted_method, weighted_method, alt=True)
    output=[]
    return [gl.network_total_throughput(M_EPs, results_list[it][-1], max_local_link_load) for it in range(len(results_list))]

# Function to calculate method_1_weights
def method_2_weights(s: int, d: int, edge_attributes: dict, alpha: float, beta: float):
    return alpha + edge_attributes['load']**beta

# Parallel computation
results = Parallel(n_jobs=10)(
    delayed(parallel_method)(alpha, beta) for alpha in _alphas for beta in _betas
)

# Process the results
for i, _alpha in enumerate(_alphas):
    for j, _beta in enumerate(_betas):
        for it in range(len(results[i * len(_betas) + j])):
            _result_Phis[it, i, j] = results[i * len(_betas) + j][it]
            print(f"calculation done for alpha={_alpha}, beta={_beta}")
            #TODO: validate the matching of data
# Out:
# done with step = 0.5 for 103 attempts.
# done with step = 0.25 for 100 attempts.
# No possible progress, terminating.
# No possible progress, terminating.
# done with step = 0.5 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.5 for 100 attempts.done with step = 0.25 for 101 attempts.
#
# done with step = 0.125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.015625 for 101 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.015625 for 101 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.5 for 100 attempts.done with step = 0.015625 for 100 attempts.
#
# done with step = 0.015625 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# No possible progress, terminating.
# done with step = 0.125 for 101 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.0625 for 101 attempts.
# done with step = 0.0625 for 101 attempts.
# done with step = 0.03125 for 100 attempts.done with step = 0.5 for 100 attempts.
#
# No possible progress, terminating.done with step = 0.03125 for 100 attempts.
#
# done with step = 0.25 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.015625 for 101 attempts.done with step = 0.03125 for 100 attempts.
# done with step = 0.5 for 100 attempts.
#
# done with step = 0.25 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.0625 for 101 attempts.
# done with step = 0.0625 for 101 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.25 for 109 attempts.
# done with step = 0.125 for 100 attempts.done with step = 0.015625 for 100 attempts.
#
# done with step = 0.125 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# No possible progress, terminating.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.5 for 101 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# No possible progress, terminating.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# No possible progress, terminating.
# done with step = 0.5 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.25 for 109 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.0625 for 101 attempts.
# done with step = 0.0625 for 101 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.03125 for 101 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.015625 for 101 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.015625 for 101 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# No possible progress, terminating.
# No possible progress, terminating.done with step = 0.015625 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
#
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.0625 for 101 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.03125 for 101 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.5 for 100 attempts.done with step = 0.5 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
#
# done with step = 0.03125 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.125 for 100 attempts.done with step = 0.125 for 100 attempts.
#
# done with step = 0.25 for 109 attempts.
# done with step = 0.5 for 100 attempts.
# No possible progress, terminating.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.5 for 100 attempts.done with step = 0.5 for 100 attempts.
#
# done with step = 0.25 for 101 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.25 for 113 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.125 for 100 attempts.done with step = 0.015625 for 100 attempts.
#
# done with step = 0.25 for 101 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.0625 for 100 attempts.done with step = 0.125 for 101 attempts.
#
# No possible progress, terminating.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.5 for 100 attempts.done with step = 0.5 for 100 attempts.
#
# done with step = 0.0625 for 101 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.25 for 109 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.0625 for 101 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.0625 for 101 attempts.
# done with step = 0.015625 for 101 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.03125 for 101 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.015625 for 101 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.125 for 100 attempts.done with step = 0.25 for 101 attempts.
#
# No possible progress, terminating.
# done with step = 0.25 for 109 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.0625 for 101 attempts.done with step = 0.125 for 100 attempts.
#
# done with step = 0.125 for 101 attempts.
# No possible progress, terminating.
# done with step = 0.25 for 100 attempts.done with step = 0.0625 for 100 attempts.
#
# done with step = 0.03125 for 101 attempts.done with step = 0.03125 for 100 attempts.
#
# done with step = 0.0625 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.015625 for 100 attempts.done with step = 0.25 for 100 attempts.
#
# done with step = 0.03125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.125 for 101 attempts.No possible progress, terminating.
# done with step = 0.5 for 100 attempts.
#
# done with step = 0.0625 for 100 attempts.
# done with step = 0.015625 for 100 attempts.done with step = 0.015625 for 100 attempts.
#
# done with step = 0.25 for 101 attempts.
# done with step = 0.0625 for 101 attempts.done with step = 0.125 for 101 attempts.
#
# done with step = 0.03125 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.0625 for 101 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.0625 for 100 attempts.done with step = 0.015625 for 100 attempts.
#
# done with step = 0.015625 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.03125 for 101 attempts.
# done with step = 0.0625 for 101 attempts.
# done with step = 0.03125 for 101 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# No possible progress, terminating.
# done with step = 0.125 for 101 attempts.
# done with step = 0.25 for 109 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.0625 for 101 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.0625 for 101 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.5 for 100 attempts.done with step = 0.25 for 100 attempts.
#
# done with step = 0.015625 for 100 attempts.done with step = 0.015625 for 100 attempts.
#
# done with step = 0.0625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.125 for 101 attempts.done with step = 0.25 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
#
# done with step = 0.03125 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.0625 for 101 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.5 for 100 attempts.done with step = 0.125 for 101 attempts.
#
# done with step = 0.125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# No possible progress, terminating.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.0625 for 101 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.015625 for 101 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.0625 for 101 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.015625 for 101 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.0625 for 101 attempts.
# done with step = 0.0625 for 100 attempts.
# No possible progress, terminating.
# done with step = 0.5 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.0625 for 101 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.015625 for 101 attempts.
# No possible progress, terminating.
# done with step = 0.03125 for 100 attempts.
# No possible progress, terminating.
# done with step = 0.015625 for 101 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.0625 for 101 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.015625 for 101 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# No possible progress, terminating.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.25 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.25 for 109 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.125 for 101 attempts.
# done with step = 0.5 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.25 for 101 attempts.
# done with step = 0.0625 for 101 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.125 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.0625 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.03125 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# done with step = 0.015625 for 100 attempts.
# calculation done for alpha=0.0, beta=0.0
# calculation done for alpha=0.0, beta=1.0
# calculation done for alpha=0.0, beta=1.0
# calculation done for alpha=0.0, beta=1.0
# calculation done for alpha=0.0, beta=2.0
# calculation done for alpha=0.0, beta=2.0
# calculation done for alpha=0.0, beta=2.0
# calculation done for alpha=0.0, beta=2.0
# calculation done for alpha=0.0, beta=2.0
# calculation done for alpha=0.0, beta=2.0
# calculation done for alpha=0.0, beta=3.0
# calculation done for alpha=0.0, beta=3.0
# calculation done for alpha=0.0, beta=3.0
# calculation done for alpha=0.0, beta=3.0
# calculation done for alpha=0.0, beta=3.0
# calculation done for alpha=0.0, beta=3.0
# calculation done for alpha=0.0, beta=4.0
# calculation done for alpha=0.0, beta=4.0
# calculation done for alpha=0.0, beta=4.0
# calculation done for alpha=0.0, beta=4.0
# calculation done for alpha=0.0, beta=4.0
# calculation done for alpha=0.0, beta=4.0
# calculation done for alpha=0.0, beta=5.0
# calculation done for alpha=0.0, beta=5.0
# calculation done for alpha=0.0, beta=5.0
# calculation done for alpha=0.0, beta=5.0
# calculation done for alpha=0.0, beta=5.0
# calculation done for alpha=0.0, beta=5.0
# calculation done for alpha=0.0, beta=6.0
# calculation done for alpha=0.0, beta=6.0
# calculation done for alpha=0.0, beta=6.0
# calculation done for alpha=0.0, beta=6.0
# calculation done for alpha=0.0, beta=6.0
# calculation done for alpha=0.0, beta=6.0
# calculation done for alpha=0.0, beta=7.0
# calculation done for alpha=0.0, beta=7.0
# calculation done for alpha=0.0, beta=7.0
# calculation done for alpha=0.0, beta=7.0
# calculation done for alpha=0.0, beta=7.0
# calculation done for alpha=0.0, beta=7.0
# calculation done for alpha=0.0, beta=8.0
# calculation done for alpha=0.0, beta=8.0
# calculation done for alpha=0.0, beta=8.0
# calculation done for alpha=0.0, beta=8.0
# calculation done for alpha=0.0, beta=8.0
# calculation done for alpha=0.0, beta=8.0
# calculation done for alpha=0.0, beta=9.0
# calculation done for alpha=0.0, beta=9.0
# calculation done for alpha=0.0, beta=9.0
# calculation done for alpha=0.0, beta=9.0
# calculation done for alpha=0.0, beta=9.0
# calculation done for alpha=0.0, beta=9.0
# calculation done for alpha=1.0, beta=0.0
# calculation done for alpha=1.0, beta=1.0
# calculation done for alpha=1.0, beta=1.0
# calculation done for alpha=1.0, beta=1.0
# calculation done for alpha=1.0, beta=2.0
# calculation done for alpha=1.0, beta=2.0
# calculation done for alpha=1.0, beta=2.0
# calculation done for alpha=1.0, beta=2.0
# calculation done for alpha=1.0, beta=2.0
# calculation done for alpha=1.0, beta=2.0
# calculation done for alpha=1.0, beta=3.0
# calculation done for alpha=1.0, beta=3.0
# calculation done for alpha=1.0, beta=3.0
# calculation done for alpha=1.0, beta=3.0
# calculation done for alpha=1.0, beta=3.0
# calculation done for alpha=1.0, beta=3.0
# calculation done for alpha=1.0, beta=4.0
# calculation done for alpha=1.0, beta=4.0
# calculation done for alpha=1.0, beta=4.0
# calculation done for alpha=1.0, beta=4.0
# calculation done for alpha=1.0, beta=4.0
# calculation done for alpha=1.0, beta=5.0
# calculation done for alpha=1.0, beta=5.0
# calculation done for alpha=1.0, beta=5.0
# calculation done for alpha=1.0, beta=5.0
# calculation done for alpha=1.0, beta=5.0
# calculation done for alpha=1.0, beta=5.0
# calculation done for alpha=1.0, beta=6.0
# calculation done for alpha=1.0, beta=6.0
# calculation done for alpha=1.0, beta=6.0
# calculation done for alpha=1.0, beta=6.0
# calculation done for alpha=1.0, beta=6.0
# calculation done for alpha=1.0, beta=6.0
# calculation done for alpha=1.0, beta=7.0
# calculation done for alpha=1.0, beta=7.0
# calculation done for alpha=1.0, beta=7.0
# calculation done for alpha=1.0, beta=7.0
# calculation done for alpha=1.0, beta=7.0
# calculation done for alpha=1.0, beta=7.0
# calculation done for alpha=1.0, beta=8.0
# calculation done for alpha=1.0, beta=8.0
# calculation done for alpha=1.0, beta=8.0
# calculation done for alpha=1.0, beta=8.0
# calculation done for alpha=1.0, beta=8.0
# calculation done for alpha=1.0, beta=8.0
# calculation done for alpha=1.0, beta=9.0
# calculation done for alpha=1.0, beta=9.0
# calculation done for alpha=1.0, beta=9.0
# calculation done for alpha=1.0, beta=9.0
# calculation done for alpha=1.0, beta=9.0
# calculation done for alpha=1.0, beta=9.0
# calculation done for alpha=2.0, beta=0.0
# calculation done for alpha=2.0, beta=1.0
# calculation done for alpha=2.0, beta=1.0
# calculation done for alpha=2.0, beta=1.0
# calculation done for alpha=2.0, beta=1.0
# calculation done for alpha=2.0, beta=2.0
# calculation done for alpha=2.0, beta=2.0
# calculation done for alpha=2.0, beta=2.0
# calculation done for alpha=2.0, beta=2.0
# calculation done for alpha=2.0, beta=2.0
# calculation done for alpha=2.0, beta=3.0
# calculation done for alpha=2.0, beta=3.0
# calculation done for alpha=2.0, beta=3.0
# calculation done for alpha=2.0, beta=3.0
# calculation done for alpha=2.0, beta=3.0
# calculation done for alpha=2.0, beta=3.0
# calculation done for alpha=2.0, beta=4.0
# calculation done for alpha=2.0, beta=4.0
# calculation done for alpha=2.0, beta=4.0
# calculation done for alpha=2.0, beta=4.0
# calculation done for alpha=2.0, beta=4.0
# calculation done for alpha=2.0, beta=4.0
# calculation done for alpha=2.0, beta=5.0
# calculation done for alpha=2.0, beta=5.0
# calculation done for alpha=2.0, beta=5.0
# calculation done for alpha=2.0, beta=5.0
# calculation done for alpha=2.0, beta=5.0
# calculation done for alpha=2.0, beta=5.0
# calculation done for alpha=2.0, beta=6.0
# calculation done for alpha=2.0, beta=6.0
# calculation done for alpha=2.0, beta=6.0
# calculation done for alpha=2.0, beta=6.0
# calculation done for alpha=2.0, beta=6.0
# calculation done for alpha=2.0, beta=6.0
# calculation done for alpha=2.0, beta=7.0
# calculation done for alpha=2.0, beta=7.0
# calculation done for alpha=2.0, beta=7.0
# calculation done for alpha=2.0, beta=7.0
# calculation done for alpha=2.0, beta=7.0
# calculation done for alpha=2.0, beta=7.0
# calculation done for alpha=2.0, beta=8.0
# calculation done for alpha=2.0, beta=8.0
# calculation done for alpha=2.0, beta=8.0
# calculation done for alpha=2.0, beta=8.0
# calculation done for alpha=2.0, beta=8.0
# calculation done for alpha=2.0, beta=8.0
# calculation done for alpha=2.0, beta=9.0
# calculation done for alpha=2.0, beta=9.0
# calculation done for alpha=2.0, beta=9.0
# calculation done for alpha=2.0, beta=9.0
# calculation done for alpha=2.0, beta=9.0
# calculation done for alpha=2.0, beta=9.0
# calculation done for alpha=3.0, beta=0.0
# calculation done for alpha=3.0, beta=1.0
# calculation done for alpha=3.0, beta=1.0
# calculation done for alpha=3.0, beta=1.0
# calculation done for alpha=3.0, beta=1.0
# calculation done for alpha=3.0, beta=1.0
# calculation done for alpha=3.0, beta=1.0
# calculation done for alpha=3.0, beta=2.0
# calculation done for alpha=3.0, beta=2.0
# calculation done for alpha=3.0, beta=2.0
# calculation done for alpha=3.0, beta=2.0
# calculation done for alpha=3.0, beta=2.0
# calculation done for alpha=3.0, beta=2.0
# calculation done for alpha=3.0, beta=3.0
# calculation done for alpha=3.0, beta=3.0
# calculation done for alpha=3.0, beta=3.0
# calculation done for alpha=3.0, beta=3.0
# calculation done for alpha=3.0, beta=3.0
# calculation done for alpha=3.0, beta=3.0
# calculation done for alpha=3.0, beta=4.0
# calculation done for alpha=3.0, beta=4.0
# calculation done for alpha=3.0, beta=4.0
# calculation done for alpha=3.0, beta=4.0
# calculation done for alpha=3.0, beta=4.0
# calculation done for alpha=3.0, beta=4.0
# calculation done for alpha=3.0, beta=5.0
# calculation done for alpha=3.0, beta=5.0
# calculation done for alpha=3.0, beta=5.0
# calculation done for alpha=3.0, beta=5.0
# calculation done for alpha=3.0, beta=5.0
# calculation done for alpha=3.0, beta=5.0
# calculation done for alpha=3.0, beta=6.0
# calculation done for alpha=3.0, beta=6.0
# calculation done for alpha=3.0, beta=6.0
# calculation done for alpha=3.0, beta=6.0
# calculation done for alpha=3.0, beta=6.0
# calculation done for alpha=3.0, beta=6.0
# calculation done for alpha=3.0, beta=7.0
# calculation done for alpha=3.0, beta=7.0
# calculation done for alpha=3.0, beta=7.0
# calculation done for alpha=3.0, beta=7.0
# calculation done for alpha=3.0, beta=7.0
# calculation done for alpha=3.0, beta=7.0
# calculation done for alpha=3.0, beta=8.0
# calculation done for alpha=3.0, beta=8.0
# calculation done for alpha=3.0, beta=8.0
# calculation done for alpha=3.0, beta=8.0
# calculation done for alpha=3.0, beta=8.0
# calculation done for alpha=3.0, beta=8.0
# calculation done for alpha=3.0, beta=9.0
# calculation done for alpha=3.0, beta=9.0
# calculation done for alpha=3.0, beta=9.0
# calculation done for alpha=3.0, beta=9.0
# calculation done for alpha=3.0, beta=9.0
# calculation done for alpha=3.0, beta=9.0
# calculation done for alpha=4.0, beta=0.0
# calculation done for alpha=4.0, beta=1.0
# calculation done for alpha=4.0, beta=1.0
# calculation done for alpha=4.0, beta=1.0
# calculation done for alpha=4.0, beta=1.0
# calculation done for alpha=4.0, beta=1.0
# calculation done for alpha=4.0, beta=1.0
# calculation done for alpha=4.0, beta=2.0
# calculation done for alpha=4.0, beta=2.0
# calculation done for alpha=4.0, beta=2.0
# calculation done for alpha=4.0, beta=2.0
# calculation done for alpha=4.0, beta=2.0
# calculation done for alpha=4.0, beta=2.0
# calculation done for alpha=4.0, beta=3.0
# calculation done for alpha=4.0, beta=3.0
# calculation done for alpha=4.0, beta=3.0
# calculation done for alpha=4.0, beta=3.0
# calculation done for alpha=4.0, beta=3.0
# calculation done for alpha=4.0, beta=3.0
# calculation done for alpha=4.0, beta=4.0
# calculation done for alpha=4.0, beta=4.0
# calculation done for alpha=4.0, beta=4.0
# calculation done for alpha=4.0, beta=4.0
# calculation done for alpha=4.0, beta=4.0
# calculation done for alpha=4.0, beta=4.0
# calculation done for alpha=4.0, beta=5.0
# calculation done for alpha=4.0, beta=5.0
# calculation done for alpha=4.0, beta=5.0
# calculation done for alpha=4.0, beta=5.0
# calculation done for alpha=4.0, beta=5.0
# calculation done for alpha=4.0, beta=5.0
# calculation done for alpha=4.0, beta=6.0
# calculation done for alpha=4.0, beta=6.0
# calculation done for alpha=4.0, beta=6.0
# calculation done for alpha=4.0, beta=6.0
# calculation done for alpha=4.0, beta=6.0
# calculation done for alpha=4.0, beta=6.0
# calculation done for alpha=4.0, beta=7.0
# calculation done for alpha=4.0, beta=7.0
# calculation done for alpha=4.0, beta=7.0
# calculation done for alpha=4.0, beta=7.0
# calculation done for alpha=4.0, beta=7.0
# calculation done for alpha=4.0, beta=7.0
# calculation done for alpha=4.0, beta=8.0
# calculation done for alpha=4.0, beta=8.0
# calculation done for alpha=4.0, beta=8.0
# calculation done for alpha=4.0, beta=8.0
# calculation done for alpha=4.0, beta=8.0
# calculation done for alpha=4.0, beta=8.0
# calculation done for alpha=4.0, beta=9.0
# calculation done for alpha=4.0, beta=9.0
# calculation done for alpha=4.0, beta=9.0
# calculation done for alpha=4.0, beta=9.0
# calculation done for alpha=4.0, beta=9.0
# calculation done for alpha=4.0, beta=9.0
# calculation done for alpha=5.0, beta=0.0
# calculation done for alpha=5.0, beta=1.0
# calculation done for alpha=5.0, beta=1.0
# calculation done for alpha=5.0, beta=1.0
# calculation done for alpha=5.0, beta=1.0
# calculation done for alpha=5.0, beta=1.0
# calculation done for alpha=5.0, beta=1.0
# calculation done for alpha=5.0, beta=2.0
# calculation done for alpha=5.0, beta=2.0
# calculation done for alpha=5.0, beta=2.0
# calculation done for alpha=5.0, beta=2.0
# calculation done for alpha=5.0, beta=2.0
# calculation done for alpha=5.0, beta=3.0
# calculation done for alpha=5.0, beta=3.0
# calculation done for alpha=5.0, beta=3.0
# calculation done for alpha=5.0, beta=3.0
# calculation done for alpha=5.0, beta=3.0
# calculation done for alpha=5.0, beta=3.0
# calculation done for alpha=5.0, beta=4.0
# calculation done for alpha=5.0, beta=4.0
# calculation done for alpha=5.0, beta=4.0
# calculation done for alpha=5.0, beta=4.0
# calculation done for alpha=5.0, beta=4.0
# calculation done for alpha=5.0, beta=4.0
# calculation done for alpha=5.0, beta=5.0
# calculation done for alpha=5.0, beta=5.0
# calculation done for alpha=5.0, beta=5.0
# calculation done for alpha=5.0, beta=5.0
# calculation done for alpha=5.0, beta=5.0
# calculation done for alpha=5.0, beta=5.0
# calculation done for alpha=5.0, beta=6.0
# calculation done for alpha=5.0, beta=6.0
# calculation done for alpha=5.0, beta=6.0
# calculation done for alpha=5.0, beta=6.0
# calculation done for alpha=5.0, beta=6.0
# calculation done for alpha=5.0, beta=6.0
# calculation done for alpha=5.0, beta=7.0
# calculation done for alpha=5.0, beta=7.0
# calculation done for alpha=5.0, beta=7.0
# calculation done for alpha=5.0, beta=7.0
# calculation done for alpha=5.0, beta=7.0
# calculation done for alpha=5.0, beta=7.0
# calculation done for alpha=5.0, beta=8.0
# calculation done for alpha=5.0, beta=8.0
# calculation done for alpha=5.0, beta=8.0
# calculation done for alpha=5.0, beta=8.0
# calculation done for alpha=5.0, beta=8.0
# calculation done for alpha=5.0, beta=8.0
# calculation done for alpha=5.0, beta=9.0
# calculation done for alpha=5.0, beta=9.0
# calculation done for alpha=5.0, beta=9.0
# calculation done for alpha=5.0, beta=9.0
# calculation done for alpha=5.0, beta=9.0
# calculation done for alpha=5.0, beta=9.0
# calculation done for alpha=6.0, beta=0.0
# calculation done for alpha=6.0, beta=1.0
# calculation done for alpha=6.0, beta=1.0
# calculation done for alpha=6.0, beta=1.0
# calculation done for alpha=6.0, beta=1.0
# calculation done for alpha=6.0, beta=1.0
# calculation done for alpha=6.0, beta=1.0
# calculation done for alpha=6.0, beta=2.0
# calculation done for alpha=6.0, beta=2.0
# calculation done for alpha=6.0, beta=2.0
# calculation done for alpha=6.0, beta=2.0
# calculation done for alpha=6.0, beta=2.0
# calculation done for alpha=6.0, beta=2.0
# calculation done for alpha=6.0, beta=3.0
# calculation done for alpha=6.0, beta=3.0
# calculation done for alpha=6.0, beta=3.0
# calculation done for alpha=6.0, beta=3.0
# calculation done for alpha=6.0, beta=3.0
# calculation done for alpha=6.0, beta=3.0
# calculation done for alpha=6.0, beta=4.0
# calculation done for alpha=6.0, beta=4.0
# calculation done for alpha=6.0, beta=4.0
# calculation done for alpha=6.0, beta=4.0
# calculation done for alpha=6.0, beta=4.0
# calculation done for alpha=6.0, beta=4.0
# calculation done for alpha=6.0, beta=5.0
# calculation done for alpha=6.0, beta=5.0
# calculation done for alpha=6.0, beta=5.0
# calculation done for alpha=6.0, beta=5.0
# calculation done for alpha=6.0, beta=5.0
# calculation done for alpha=6.0, beta=5.0
# calculation done for alpha=6.0, beta=6.0
# calculation done for alpha=6.0, beta=6.0
# calculation done for alpha=6.0, beta=6.0
# calculation done for alpha=6.0, beta=6.0
# calculation done for alpha=6.0, beta=6.0
# calculation done for alpha=6.0, beta=6.0
# calculation done for alpha=6.0, beta=7.0
# calculation done for alpha=6.0, beta=7.0
# calculation done for alpha=6.0, beta=7.0
# calculation done for alpha=6.0, beta=7.0
# calculation done for alpha=6.0, beta=7.0
# calculation done for alpha=6.0, beta=7.0
# calculation done for alpha=6.0, beta=8.0
# calculation done for alpha=6.0, beta=8.0
# calculation done for alpha=6.0, beta=8.0
# calculation done for alpha=6.0, beta=8.0
# calculation done for alpha=6.0, beta=8.0
# calculation done for alpha=6.0, beta=8.0
# calculation done for alpha=6.0, beta=9.0
# calculation done for alpha=6.0, beta=9.0
# calculation done for alpha=6.0, beta=9.0
# calculation done for alpha=6.0, beta=9.0
# calculation done for alpha=6.0, beta=9.0
# calculation done for alpha=6.0, beta=9.0
# calculation done for alpha=7.0, beta=0.0
# calculation done for alpha=7.0, beta=1.0
# calculation done for alpha=7.0, beta=1.0
# calculation done for alpha=7.0, beta=1.0
# calculation done for alpha=7.0, beta=1.0
# calculation done for alpha=7.0, beta=1.0
# calculation done for alpha=7.0, beta=1.0
# calculation done for alpha=7.0, beta=2.0
# calculation done for alpha=7.0, beta=2.0
# calculation done for alpha=7.0, beta=2.0
# calculation done for alpha=7.0, beta=2.0
# calculation done for alpha=7.0, beta=2.0
# calculation done for alpha=7.0, beta=2.0
# calculation done for alpha=7.0, beta=3.0
# calculation done for alpha=7.0, beta=3.0
# calculation done for alpha=7.0, beta=3.0
# calculation done for alpha=7.0, beta=3.0
# calculation done for alpha=7.0, beta=3.0
# calculation done for alpha=7.0, beta=3.0
# calculation done for alpha=7.0, beta=4.0
# calculation done for alpha=7.0, beta=4.0
# calculation done for alpha=7.0, beta=4.0
# calculation done for alpha=7.0, beta=4.0
# calculation done for alpha=7.0, beta=4.0
# calculation done for alpha=7.0, beta=4.0
# calculation done for alpha=7.0, beta=5.0
# calculation done for alpha=7.0, beta=5.0
# calculation done for alpha=7.0, beta=5.0
# calculation done for alpha=7.0, beta=5.0
# calculation done for alpha=7.0, beta=5.0
# calculation done for alpha=7.0, beta=5.0
# calculation done for alpha=7.0, beta=6.0
# calculation done for alpha=7.0, beta=6.0
# calculation done for alpha=7.0, beta=6.0
# calculation done for alpha=7.0, beta=6.0
# calculation done for alpha=7.0, beta=6.0
# calculation done for alpha=7.0, beta=6.0
# calculation done for alpha=7.0, beta=7.0
# calculation done for alpha=7.0, beta=7.0
# calculation done for alpha=7.0, beta=7.0
# calculation done for alpha=7.0, beta=7.0
# calculation done for alpha=7.0, beta=7.0
# calculation done for alpha=7.0, beta=7.0
# calculation done for alpha=7.0, beta=8.0
# calculation done for alpha=7.0, beta=8.0
# calculation done for alpha=7.0, beta=8.0
# calculation done for alpha=7.0, beta=8.0
# calculation done for alpha=7.0, beta=8.0
# calculation done for alpha=7.0, beta=8.0
# calculation done for alpha=7.0, beta=9.0
# calculation done for alpha=7.0, beta=9.0
# calculation done for alpha=7.0, beta=9.0
# calculation done for alpha=7.0, beta=9.0
# calculation done for alpha=7.0, beta=9.0
# calculation done for alpha=7.0, beta=9.0
# calculation done for alpha=8.0, beta=0.0
# calculation done for alpha=8.0, beta=1.0
# calculation done for alpha=8.0, beta=1.0
# calculation done for alpha=8.0, beta=1.0
# calculation done for alpha=8.0, beta=1.0
# calculation done for alpha=8.0, beta=1.0
# calculation done for alpha=8.0, beta=1.0
# calculation done for alpha=8.0, beta=2.0
# calculation done for alpha=8.0, beta=2.0
# calculation done for alpha=8.0, beta=2.0
# calculation done for alpha=8.0, beta=2.0
# calculation done for alpha=8.0, beta=2.0
# calculation done for alpha=8.0, beta=2.0
# calculation done for alpha=8.0, beta=3.0
# calculation done for alpha=8.0, beta=3.0
# calculation done for alpha=8.0, beta=3.0
# calculation done for alpha=8.0, beta=3.0
# calculation done for alpha=8.0, beta=3.0
# calculation done for alpha=8.0, beta=3.0
# calculation done for alpha=8.0, beta=4.0
# calculation done for alpha=8.0, beta=4.0
# calculation done for alpha=8.0, beta=4.0
# calculation done for alpha=8.0, beta=4.0
# calculation done for alpha=8.0, beta=4.0
# calculation done for alpha=8.0, beta=4.0
# calculation done for alpha=8.0, beta=5.0
# calculation done for alpha=8.0, beta=5.0
# calculation done for alpha=8.0, beta=5.0
# calculation done for alpha=8.0, beta=5.0
# calculation done for alpha=8.0, beta=5.0
# calculation done for alpha=8.0, beta=5.0
# calculation done for alpha=8.0, beta=6.0
# calculation done for alpha=8.0, beta=6.0
# calculation done for alpha=8.0, beta=6.0
# calculation done for alpha=8.0, beta=6.0
# calculation done for alpha=8.0, beta=6.0
# calculation done for alpha=8.0, beta=7.0
# calculation done for alpha=8.0, beta=7.0
# calculation done for alpha=8.0, beta=7.0
# calculation done for alpha=8.0, beta=7.0
# calculation done for alpha=8.0, beta=7.0
# calculation done for alpha=8.0, beta=7.0
# calculation done for alpha=8.0, beta=8.0
# calculation done for alpha=8.0, beta=8.0
# calculation done for alpha=8.0, beta=8.0
# calculation done for alpha=8.0, beta=8.0
# calculation done for alpha=8.0, beta=8.0
# calculation done for alpha=8.0, beta=8.0
# calculation done for alpha=8.0, beta=9.0
# calculation done for alpha=8.0, beta=9.0
# calculation done for alpha=8.0, beta=9.0
# calculation done for alpha=8.0, beta=9.0
# calculation done for alpha=8.0, beta=9.0
# calculation done for alpha=8.0, beta=9.0
# calculation done for alpha=9.0, beta=0.0
# calculation done for alpha=9.0, beta=1.0
# calculation done for alpha=9.0, beta=1.0
# calculation done for alpha=9.0, beta=1.0
# calculation done for alpha=9.0, beta=1.0
# calculation done for alpha=9.0, beta=1.0
# calculation done for alpha=9.0, beta=1.0
# calculation done for alpha=9.0, beta=2.0
# calculation done for alpha=9.0, beta=2.0
# calculation done for alpha=9.0, beta=2.0
# calculation done for alpha=9.0, beta=2.0
# calculation done for alpha=9.0, beta=2.0
# calculation done for alpha=9.0, beta=2.0
# calculation done for alpha=9.0, beta=3.0
# calculation done for alpha=9.0, beta=3.0
# calculation done for alpha=9.0, beta=3.0
# calculation done for alpha=9.0, beta=3.0
# calculation done for alpha=9.0, beta=3.0
# calculation done for alpha=9.0, beta=3.0
# calculation done for alpha=9.0, beta=4.0
# calculation done for alpha=9.0, beta=4.0
# calculation done for alpha=9.0, beta=4.0
# calculation done for alpha=9.0, beta=4.0
# calculation done for alpha=9.0, beta=4.0
# calculation done for alpha=9.0, beta=4.0
# calculation done for alpha=9.0, beta=5.0
# calculation done for alpha=9.0, beta=5.0
# calculation done for alpha=9.0, beta=5.0
# calculation done for alpha=9.0, beta=5.0
# calculation done for alpha=9.0, beta=5.0
# calculation done for alpha=9.0, beta=5.0
# calculation done for alpha=9.0, beta=6.0
# calculation done for alpha=9.0, beta=6.0
# calculation done for alpha=9.0, beta=6.0
# calculation done for alpha=9.0, beta=6.0
# calculation done for alpha=9.0, beta=6.0
# calculation done for alpha=9.0, beta=7.0
# calculation done for alpha=9.0, beta=7.0
# calculation done for alpha=9.0, beta=7.0
# calculation done for alpha=9.0, beta=7.0
# calculation done for alpha=9.0, beta=7.0
# calculation done for alpha=9.0, beta=7.0
# calculation done for alpha=9.0, beta=8.0
# calculation done for alpha=9.0, beta=8.0
# calculation done for alpha=9.0, beta=8.0
# calculation done for alpha=9.0, beta=8.0
# calculation done for alpha=9.0, beta=8.0
# calculation done for alpha=9.0, beta=8.0
# calculation done for alpha=9.0, beta=9.0
# calculation done for alpha=9.0, beta=9.0
# calculation done for alpha=9.0, beta=9.0
# calculation done for alpha=9.0, beta=9.0
# calculation done for alpha=9.0, beta=9.0
# calculation done for alpha=9.0, beta=9.0

# %%
_result_Phis
# Out:
# array([[[180.        , 216.        , 308.57142857, 308.57142857,
#          308.57142857, 308.57142857, 308.57142857, 308.57142857,
#          308.57142857, 308.57142857],
#         [180.        , 308.57142857, 270.        , 308.57142857,
#          308.57142857, 308.57142857, 308.57142857, 308.57142857,
#          308.57142857, 308.57142857],
#         [180.        , 270.        , 270.        , 308.57142857,
#          308.57142857, 308.57142857, 308.57142857, 308.57142857,
#          308.57142857, 308.57142857],
#         [180.        , 216.        , 270.        , 308.57142857,
#          308.57142857, 308.57142857, 308.57142857, 308.57142857,
#          308.57142857, 308.57142857],
#         [180.        , 216.        , 308.57142857, 308.57142857,
#          308.57142857, 308.57142857, 308.57142857, 308.57142857,
#          308.57142857, 308.57142857],
#         [180.        , 216.        , 270.        , 308.57142857,
#          308.57142857, 308.57142857, 308.57142857, 308.57142857,
#          308.57142857, 308.57142857],
#         [180.        , 216.        , 308.57142857, 308.57142857,
#          308.57142857, 308.57142857, 308.57142857, 308.57142857,
#          308.57142857, 308.57142857],
#         [180.        , 216.        , 308.57142857, 308.57142857,
#          308.57142857, 308.57142857, 308.57142857, 308.57142857,
#          308.57142857, 308.57142857],
#         [180.        , 216.        , 308.57142857, 308.57142857,
#          308.57142857, 308.57142857, 308.57142857, 308.57142857,
#          308.57142857, 308.57142857],
#         [180.        , 216.        , 308.57142857, 308.57142857,
#          308.57142857, 308.57142857, 308.57142857, 308.57142857,
#          308.57142857, 308.57142857]],
#
#        [[  0.        , 308.57142857, 308.57142857, 308.57142857,
#          308.57142857, 308.57142857, 308.57142857, 308.57142857,
#          308.57142857, 308.57142857],
#         [  0.        , 288.        , 288.        , 308.57142857,
#          308.57142857, 308.57142857, 308.57142857, 308.57142857,
#          308.57142857, 332.30769231],
#         [  0.        , 288.        , 288.        , 308.57142857,
#          308.57142857, 308.57142857, 308.57142857, 308.57142857,
#          308.57142857, 332.30769231],
#         [  0.        , 270.        , 288.        , 308.57142857,
#          308.57142857, 308.57142857, 308.57142857, 308.57142857,
#          308.57142857, 332.30769231],
#         [  0.        , 240.        , 308.57142857, 308.57142857,
#          308.57142857, 308.57142857, 308.57142857, 308.57142857,
#          332.30769231, 332.30769231],
#         [  0.        , 227.36842105, 288.        , 288.        ,
#          308.57142857, 308.57142857, 308.57142857, 308.57142857,
#          308.57142857, 332.30769231],
#         [  0.        , 227.36842105, 308.57142857, 308.57142857,
#          308.57142857, 308.57142857, 308.57142857, 308.57142857,
#          308.57142857, 332.30769231],
#         [  0.        , 227.36842105, 308.57142857, 308.57142857,
#          308.57142857, 308.57142857, 308.57142857, 308.57142857,
#          308.57142857, 308.57142857],
#         [  0.        , 227.36842105, 308.57142857, 308.57142857,
#          308.57142857, 308.57142857, 308.57142857, 308.57142857,
#          308.57142857, 308.57142857],
#         [  0.        , 227.36842105, 308.57142857, 308.57142857,
#          308.57142857, 308.57142857, 308.57142857, 308.57142857,
#          308.57142857, 332.30769231]],
#
#        [[  0.        , 320.        , 308.57142857, 345.6       ,
#          345.6       , 345.6       , 345.6       , 345.6       ,
#          345.6       , 360.        ],
#         [  0.        , 320.        , 332.30769231, 345.6       ,
#          345.6       , 345.6       , 345.6       , 345.6       ,
#          345.6       , 345.6       ],
#         [  0.        , 308.57142857, 320.        , 332.30769231,
#          345.6       , 345.6       , 345.6       , 345.6       ,
#          345.6       , 345.6       ],
#         [  0.        , 288.        , 320.        , 345.6       ,
#          345.6       , 345.6       , 345.6       , 345.6       ,
#          345.6       , 345.6       ],
#         [  0.        , 254.11764706, 345.6       , 345.6       ,
#          345.6       , 345.6       , 345.6       , 345.6       ,
#          345.6       , 345.6       ],
#         [  0.        , 246.85714286, 320.        , 308.57142857,
#          345.6       , 345.6       , 345.6       , 345.6       ,
#          345.6       , 345.6       ],
#         [  0.        , 246.85714286, 308.57142857, 320.        ,
#          345.6       , 345.6       , 345.6       , 345.6       ,
#          345.6       , 345.6       ],
#         [  0.        , 246.85714286, 308.57142857, 320.        ,
#          345.6       , 345.6       , 345.6       , 345.6       ,
#          345.6       , 345.6       ],
#         [  0.        , 246.85714286, 308.57142857, 320.        ,
#          345.6       , 345.6       , 345.6       , 345.6       ,
#          345.6       , 345.6       ],
#         [  0.        , 246.85714286, 308.57142857, 332.30769231,
#          345.6       , 360.        , 345.6       , 345.6       ,
#          345.6       , 345.6       ]],
#
#        [[  0.        ,   0.        , 345.6       , 360.        ,
#          345.6       , 345.6       , 345.6       , 360.        ,
#          360.        , 367.65957447],
#         [  0.        ,   0.        , 360.        , 360.        ,
#          360.        , 367.65957447, 360.        , 360.        ,
#          367.65957447, 367.65957447],
#         [  0.        , 308.57142857, 338.82352941, 345.6       ,
#          367.65957447, 367.65957447, 360.        , 360.        ,
#          367.65957447, 367.65957447],
#         [  0.        , 292.88135593, 338.82352941, 360.        ,
#          367.65957447, 367.65957447, 360.        , 367.65957447,
#          367.65957447, 367.65957447],
#         [  0.        , 261.81818182, 345.6       , 360.        ,
#          367.65957447, 367.65957447, 360.        , 360.        ,
#          367.65957447, 367.65957447],
#         [  0.        , 254.11764706, 338.82352941, 360.        ,
#          360.        , 360.        , 360.        , 360.        ,
#          367.65957447, 367.65957447],
#         [  0.        , 254.11764706, 345.6       , 338.82352941,
#          360.        , 360.        , 360.        , 367.65957447,
#          367.65957447, 367.65957447],
#         [  0.        , 254.11764706, 320.        , 345.6       ,
#          360.        , 360.        , 367.65957447, 367.65957447,
#          367.65957447, 360.        ],
#         [  0.        , 254.11764706, 338.82352941, 345.6       ,
#          360.        , 360.        , 367.65957447, 360.        ,
#          360.        , 360.        ],
#         [  0.        , 254.11764706, 345.6       , 345.6       ,
#          360.        , 360.        , 367.65957447, 367.65957447,
#          367.65957447, 367.65957447]],
#
#        [[  0.        ,   0.        , 345.6       , 360.        ,
#          356.28865979, 367.65957447, 356.28865979, 371.61290323,
#          367.65957447, 367.65957447],
#         [  0.        ,   0.        , 360.        , 360.        ,
#          360.        , 371.61290323, 379.78021978, 379.78021978,
#          367.65957447, 379.78021978],
#         [  0.        ,   0.        , 338.82352941, 352.65306122,
#          367.65957447, 367.65957447, 379.78021978, 379.78021978,
#          367.65957447, 379.78021978],
#         [  0.        , 305.84070796, 338.82352941, 360.        ,
#          367.65957447, 367.65957447, 379.78021978, 384.        ,
#          367.65957447, 379.78021978],
#         [  0.        , 265.84615385, 345.6       , 371.61290323,
#          371.61290323, 367.65957447, 379.78021978, 379.78021978,
#          367.65957447, 379.78021978],
#         [  0.        , 257.91044776, 338.82352941, 360.        ,
#          367.65957447, 360.        , 379.78021978, 379.78021978,
#          367.65957447, 379.78021978],
#         [  0.        , 257.91044776, 345.6       , 349.09090909,
#          367.65957447, 360.        , 379.78021978, 384.        ,
#          367.65957447, 379.78021978],
#         [  0.        , 254.11764706, 345.6       , 349.09090909,
#          367.65957447, 360.        , 379.78021978, 384.        ,
#          367.65957447, 371.61290323],
#         [  0.        , 254.11764706, 345.6       , 349.09090909,
#          371.61290323, 360.        , 371.61290323, 379.78021978,
#          367.65957447, 371.61290323],
#         [  0.        , 248.63309353, 345.6       , 352.65306122,
#          371.61290323, 360.        , 371.61290323, 384.        ,
#          367.65957447, 379.78021978]],
#
#        [[  0.        ,   0.        , 360.        , 360.        ,
#          360.        , 367.65957447, 356.28865979, 371.61290323,
#          373.62162162, 371.61290323],
#         [  0.        ,   0.        , 360.        , 360.        ,
#            0.        , 371.61290323, 377.70491803, 379.78021978,
#          379.78021978, 379.78021978],
#         [  0.        ,   0.        ,   0.        , 356.28865979,
#          373.62162162, 373.62162162, 377.70491803, 379.78021978,
#          379.78021978, 379.78021978],
#         [  0.        , 314.18181818, 338.82352941, 360.        ,
#          371.61290323, 373.62162162, 377.70491803, 384.        ,
#          379.78021978, 379.78021978],
#         [  0.        , 267.90697674, 356.28865979, 371.61290323,
#          371.61290323, 373.62162162, 377.70491803, 379.78021978,
#          377.70491803, 379.78021978],
#         [  0.        , 259.84962406,   0.        , 365.71428571,
#          371.61290323, 360.        , 377.70491803, 379.78021978,
#          379.78021978, 379.78021978],
#         [  0.        , 259.84962406, 345.6       , 349.09090909,
#          371.61290323, 360.        , 377.70491803, 384.        ,
#          379.78021978, 379.78021978],
#         [  0.        , 254.11764706, 345.6       , 349.09090909,
#          371.61290323, 360.        , 379.78021978, 384.        ,
#          379.78021978, 377.70491803],
#         [  0.        , 254.11764706, 345.6       , 349.09090909,
#          377.70491803, 360.        ,   0.        , 379.78021978,
#          373.62162162, 377.70491803],
#         [  0.        , 251.34545455, 345.6       , 356.28865979,
#          377.70491803, 360.        ,   0.        , 384.        ,
#          379.78021978, 379.78021978]]])

# %% [markdown]
# # plot

# %%
# OPTIMUM= 742 # Nexullance_OPT [GBps]

# colors=['red', 'orangered', 'gold', 'yellowgreen']

# fig = plt.figure()
# ax = fig.add_subplot(projection='3d')
# for i, _alpha in enumerate(_alphas):
#     for j, _beta in enumerate(_betas):
#         for it in range(num_method_1):
#             ax.scatter(_alpha, _beta, _result_Phis[it,i,j]/OPTIMUM, marker='o', c = colors[it], label =f"{it} times")

# ax.set_xlabel('alpha')
# ax.set_ylabel('beta')
# ax.set_zlabel('achieved $\Phi$ (normalized to Nexullance_OPT)')

# ax.set_zlim([0,1])

# plt.legend()

# plt.show()

# %%
OPTIMUM = 450.0  # Nexullance_OPT [GBps]
colors = ['red', 'gold', 'limegreen', 'deepskyblue', 'mediumslateblue', 'darkorchid']
# colors = ['red', 'orangered', 'gold', 'yellowgreen', 'limegreen', 
#           'lightseagreen', 'deepskyblue', 'royalblue', 'mediumslateblue', 'darkorchid']


fig = plt.figure()
ax = fig.add_subplot(projection='3d')

legend_handles = []  # List to store legend handles
legend_labels = []   # List to store legend labels

for i, _alpha in enumerate(_alphas):
    for j, _beta in enumerate(_betas):
        for it in range(num_method_2):
            if _result_Phis[it, i, j] != 0:
                # Scatter plot
                ax.scatter(_alpha, _beta, _result_Phis[it, i, j] / OPTIMUM,
                        marker='o', c=colors[it])

# Create legend handles and labels for each color
for it, color in enumerate(colors):
    legend_handles.append(ax.scatter([], [], [], c=color, label=f"{it+1} times"))
    legend_labels.append(f"{it+1} times")

ax.set_xlabel('alpha')
ax.set_ylabel('beta')
ax.set_zlabel('achieved $\Phi$ (normalized to Nexullance_OPT)')
ax.set_zlim([0, 1])

# Plot legend with the handles and labels created
plt.legend(handles=legend_handles, labels=legend_labels)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.max(_result_Phis)/OPTIMUM
# Out:
# 0.8533333333333332

# %%
np.argmax(_result_Phis)
# Out:
# 437

# %%
_result_Phis[:,3,7]/OPTIMUM
# Out:
# array([0.68571429, 0.68571429, 0.768     , 0.81702128, 0.85333333,
#        0.85333333])
