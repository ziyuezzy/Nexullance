# %%
import matplotlib.pyplot as plt
import numpy as np
from Nexullance_IT import Nexullance_IT
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../..')))
from topologies.DDF import DDFtopo
import globals as gl
import copy
from joblib import Parallel, delayed
# %matplotlib widget

# %% [markdown]
# # setup network, not yet using nexullance

# %%
config=(36, 5)
EPR=3
ddf_network = DDFtopo(config[0], config[1])
Cap_remote = 10 #GBps
Cap_local = 10 #GBps
M_EPs = gl.generate_uniform_traffic_pattern(config[0], EPR) # an numpy matrix filled with ones
scaling_factor = 1
M_EPs = scaling_factor * M_EPs
M_R = gl.convert_M_EPs_to_M_R(M_EPs, config[0], EPR)

# %%
ASP = ddf_network.calculate_all_shortest_paths()
ECMP_ASP = gl.ECMP(ASP)
remote_link_flows, local_link_flows = ddf_network.distribute_M_EPs_on_weighted_paths(ECMP_ASP, EPR, M_EPs)
max_remote_link_load = np.max(remote_link_flows)/Cap_remote
max_local_link_load = np.max(local_link_flows)/Cap_local
print("Max remote link load: ", max_remote_link_load)
print("Max local link load: ", max_local_link_load)
if max_remote_link_load > 1.0 or max_local_link_load > 1.0:
    print("network congestion may present")
    mu = max_local_link_load/max_remote_link_load
    if mu > 1.0:
        print(f"mu = {mu} > 1, max local link load is higher")
    else:
        print(f"mu = {mu} < 1, max remote link load is higher")
else:
    print("network is probably not congested")
print("network_total_throughput = ", gl.network_total_throughput(M_EPs, max_remote_link_load, max_local_link_load), "GBps")
# Out:
# Max remote link load:  20.775
# Max local link load:  10.7
# network congestion may present
# mu = 0.5150421179302046 < 1, max remote link load is higher
# network_total_throughput =  556.245487364621 GBps

# %% [markdown]
# # start to sweep parameters

# %%
# initialize data
_alphas = np.array(list(range(0, 100, 10)), dtype=float)
_betas = np.array(list(np.arange(0.0, 4.0, 0.4)), dtype=float)

num_method_1 = 4
_result_Phis = np.ndarray((num_method_1, len(_alphas), len(_betas)), dtype=float)*0 
# the first dimension corresponds to iterations

# %%
nexu_it = Nexullance_IT(ddf_network.nx_graph, M_R, Cap_remote)

# %%
# Function to be executed in parallel
def parallel_method(alpha, beta):
    nexu_it_test = copy.deepcopy(nexu_it)
    def weighted_method(s: int, d: int, edge_attributes: dict):
        return method_1_weights(s, d, edge_attributes, alpha, beta)
    result_list, _ = nexu_it_test.optimize(num_method_1, 0, weighted_method, None)
    return [gl.network_total_throughput(M_EPs, result_list[it], max_local_link_load) for it in range(num_method_1)]

# Function to calculate method_1_weights
def method_1_weights(s: int, d: int, edge_attributes: dict, alpha: float, beta: float):
    return alpha + edge_attributes['load']**beta

# Parallel computation
results = Parallel(n_jobs=10)(
    delayed(parallel_method)(alpha, beta) for alpha in _alphas for beta in _betas
)

# Process the results
for i, _alpha in enumerate(_alphas):
    for j, _beta in enumerate(_betas):
        for it in range(num_method_1):
            _result_Phis[it, i, j] = results[i * len(_betas) + j][it]
            print(f"calculation done for alpha={_alpha}, beta={_beta}")
            #TODO: validate the matching of data
# Out:
# calculation done for alpha=0.0, beta=0.0
# calculation done for alpha=0.0, beta=0.0
# calculation done for alpha=0.0, beta=0.0
# calculation done for alpha=0.0, beta=0.0
# calculation done for alpha=0.0, beta=0.4
# calculation done for alpha=0.0, beta=0.4
# calculation done for alpha=0.0, beta=0.4
# calculation done for alpha=0.0, beta=0.4
# calculation done for alpha=0.0, beta=0.8
# calculation done for alpha=0.0, beta=0.8
# calculation done for alpha=0.0, beta=0.8
# calculation done for alpha=0.0, beta=0.8
# calculation done for alpha=0.0, beta=1.2000000000000002
# calculation done for alpha=0.0, beta=1.2000000000000002
# calculation done for alpha=0.0, beta=1.2000000000000002
# calculation done for alpha=0.0, beta=1.2000000000000002
# calculation done for alpha=0.0, beta=1.6
# calculation done for alpha=0.0, beta=1.6
# calculation done for alpha=0.0, beta=1.6
# calculation done for alpha=0.0, beta=1.6
# calculation done for alpha=0.0, beta=2.0
# calculation done for alpha=0.0, beta=2.0
# calculation done for alpha=0.0, beta=2.0
# calculation done for alpha=0.0, beta=2.0
# calculation done for alpha=0.0, beta=2.4000000000000004
# calculation done for alpha=0.0, beta=2.4000000000000004
# calculation done for alpha=0.0, beta=2.4000000000000004
# calculation done for alpha=0.0, beta=2.4000000000000004
# calculation done for alpha=0.0, beta=2.8000000000000003
# calculation done for alpha=0.0, beta=2.8000000000000003
# calculation done for alpha=0.0, beta=2.8000000000000003
# calculation done for alpha=0.0, beta=2.8000000000000003
# calculation done for alpha=0.0, beta=3.2
# calculation done for alpha=0.0, beta=3.2
# calculation done for alpha=0.0, beta=3.2
# calculation done for alpha=0.0, beta=3.2
# calculation done for alpha=0.0, beta=3.6
# calculation done for alpha=0.0, beta=3.6
# calculation done for alpha=0.0, beta=3.6
# calculation done for alpha=0.0, beta=3.6
# calculation done for alpha=10.0, beta=0.0
# calculation done for alpha=10.0, beta=0.0
# calculation done for alpha=10.0, beta=0.0
# calculation done for alpha=10.0, beta=0.0
# calculation done for alpha=10.0, beta=0.4
# calculation done for alpha=10.0, beta=0.4
# calculation done for alpha=10.0, beta=0.4
# calculation done for alpha=10.0, beta=0.4
# calculation done for alpha=10.0, beta=0.8
# calculation done for alpha=10.0, beta=0.8
# calculation done for alpha=10.0, beta=0.8
# calculation done for alpha=10.0, beta=0.8
# calculation done for alpha=10.0, beta=1.2000000000000002
# calculation done for alpha=10.0, beta=1.2000000000000002
# calculation done for alpha=10.0, beta=1.2000000000000002
# calculation done for alpha=10.0, beta=1.2000000000000002
# calculation done for alpha=10.0, beta=1.6
# calculation done for alpha=10.0, beta=1.6
# calculation done for alpha=10.0, beta=1.6
# calculation done for alpha=10.0, beta=1.6
# calculation done for alpha=10.0, beta=2.0
# calculation done for alpha=10.0, beta=2.0
# calculation done for alpha=10.0, beta=2.0
# calculation done for alpha=10.0, beta=2.0
# calculation done for alpha=10.0, beta=2.4000000000000004
# calculation done for alpha=10.0, beta=2.4000000000000004
# calculation done for alpha=10.0, beta=2.4000000000000004
# calculation done for alpha=10.0, beta=2.4000000000000004
# calculation done for alpha=10.0, beta=2.8000000000000003
# calculation done for alpha=10.0, beta=2.8000000000000003
# calculation done for alpha=10.0, beta=2.8000000000000003
# calculation done for alpha=10.0, beta=2.8000000000000003
# calculation done for alpha=10.0, beta=3.2
# calculation done for alpha=10.0, beta=3.2
# calculation done for alpha=10.0, beta=3.2
# calculation done for alpha=10.0, beta=3.2
# calculation done for alpha=10.0, beta=3.6
# calculation done for alpha=10.0, beta=3.6
# calculation done for alpha=10.0, beta=3.6
# calculation done for alpha=10.0, beta=3.6
# calculation done for alpha=20.0, beta=0.0
# calculation done for alpha=20.0, beta=0.0
# calculation done for alpha=20.0, beta=0.0
# calculation done for alpha=20.0, beta=0.0
# calculation done for alpha=20.0, beta=0.4
# calculation done for alpha=20.0, beta=0.4
# calculation done for alpha=20.0, beta=0.4
# calculation done for alpha=20.0, beta=0.4
# calculation done for alpha=20.0, beta=0.8
# calculation done for alpha=20.0, beta=0.8
# calculation done for alpha=20.0, beta=0.8
# calculation done for alpha=20.0, beta=0.8
# calculation done for alpha=20.0, beta=1.2000000000000002
# calculation done for alpha=20.0, beta=1.2000000000000002
# calculation done for alpha=20.0, beta=1.2000000000000002
# calculation done for alpha=20.0, beta=1.2000000000000002
# calculation done for alpha=20.0, beta=1.6
# calculation done for alpha=20.0, beta=1.6
# calculation done for alpha=20.0, beta=1.6
# calculation done for alpha=20.0, beta=1.6
# calculation done for alpha=20.0, beta=2.0
# calculation done for alpha=20.0, beta=2.0
# calculation done for alpha=20.0, beta=2.0
# calculation done for alpha=20.0, beta=2.0
# calculation done for alpha=20.0, beta=2.4000000000000004
# calculation done for alpha=20.0, beta=2.4000000000000004
# calculation done for alpha=20.0, beta=2.4000000000000004
# calculation done for alpha=20.0, beta=2.4000000000000004
# calculation done for alpha=20.0, beta=2.8000000000000003
# calculation done for alpha=20.0, beta=2.8000000000000003
# calculation done for alpha=20.0, beta=2.8000000000000003
# calculation done for alpha=20.0, beta=2.8000000000000003
# calculation done for alpha=20.0, beta=3.2
# calculation done for alpha=20.0, beta=3.2
# calculation done for alpha=20.0, beta=3.2
# calculation done for alpha=20.0, beta=3.2
# calculation done for alpha=20.0, beta=3.6
# calculation done for alpha=20.0, beta=3.6
# calculation done for alpha=20.0, beta=3.6
# calculation done for alpha=20.0, beta=3.6
# calculation done for alpha=30.0, beta=0.0
# calculation done for alpha=30.0, beta=0.0
# calculation done for alpha=30.0, beta=0.0
# calculation done for alpha=30.0, beta=0.0
# calculation done for alpha=30.0, beta=0.4
# calculation done for alpha=30.0, beta=0.4
# calculation done for alpha=30.0, beta=0.4
# calculation done for alpha=30.0, beta=0.4
# calculation done for alpha=30.0, beta=0.8
# calculation done for alpha=30.0, beta=0.8
# calculation done for alpha=30.0, beta=0.8
# calculation done for alpha=30.0, beta=0.8
# calculation done for alpha=30.0, beta=1.2000000000000002
# calculation done for alpha=30.0, beta=1.2000000000000002
# calculation done for alpha=30.0, beta=1.2000000000000002
# calculation done for alpha=30.0, beta=1.2000000000000002
# calculation done for alpha=30.0, beta=1.6
# calculation done for alpha=30.0, beta=1.6
# calculation done for alpha=30.0, beta=1.6
# calculation done for alpha=30.0, beta=1.6
# calculation done for alpha=30.0, beta=2.0
# calculation done for alpha=30.0, beta=2.0
# calculation done for alpha=30.0, beta=2.0
# calculation done for alpha=30.0, beta=2.0
# calculation done for alpha=30.0, beta=2.4000000000000004
# calculation done for alpha=30.0, beta=2.4000000000000004
# calculation done for alpha=30.0, beta=2.4000000000000004
# calculation done for alpha=30.0, beta=2.4000000000000004
# calculation done for alpha=30.0, beta=2.8000000000000003
# calculation done for alpha=30.0, beta=2.8000000000000003
# calculation done for alpha=30.0, beta=2.8000000000000003
# calculation done for alpha=30.0, beta=2.8000000000000003
# calculation done for alpha=30.0, beta=3.2
# calculation done for alpha=30.0, beta=3.2
# calculation done for alpha=30.0, beta=3.2
# calculation done for alpha=30.0, beta=3.2
# calculation done for alpha=30.0, beta=3.6
# calculation done for alpha=30.0, beta=3.6
# calculation done for alpha=30.0, beta=3.6
# calculation done for alpha=30.0, beta=3.6
# calculation done for alpha=40.0, beta=0.0
# calculation done for alpha=40.0, beta=0.0
# calculation done for alpha=40.0, beta=0.0
# calculation done for alpha=40.0, beta=0.0
# calculation done for alpha=40.0, beta=0.4
# calculation done for alpha=40.0, beta=0.4
# calculation done for alpha=40.0, beta=0.4
# calculation done for alpha=40.0, beta=0.4
# calculation done for alpha=40.0, beta=0.8
# calculation done for alpha=40.0, beta=0.8
# calculation done for alpha=40.0, beta=0.8
# calculation done for alpha=40.0, beta=0.8
# calculation done for alpha=40.0, beta=1.2000000000000002
# calculation done for alpha=40.0, beta=1.2000000000000002
# calculation done for alpha=40.0, beta=1.2000000000000002
# calculation done for alpha=40.0, beta=1.2000000000000002
# calculation done for alpha=40.0, beta=1.6
# calculation done for alpha=40.0, beta=1.6
# calculation done for alpha=40.0, beta=1.6
# calculation done for alpha=40.0, beta=1.6
# calculation done for alpha=40.0, beta=2.0
# calculation done for alpha=40.0, beta=2.0
# calculation done for alpha=40.0, beta=2.0
# calculation done for alpha=40.0, beta=2.0
# calculation done for alpha=40.0, beta=2.4000000000000004
# calculation done for alpha=40.0, beta=2.4000000000000004
# calculation done for alpha=40.0, beta=2.4000000000000004
# calculation done for alpha=40.0, beta=2.4000000000000004
# calculation done for alpha=40.0, beta=2.8000000000000003
# calculation done for alpha=40.0, beta=2.8000000000000003
# calculation done for alpha=40.0, beta=2.8000000000000003
# calculation done for alpha=40.0, beta=2.8000000000000003
# calculation done for alpha=40.0, beta=3.2
# calculation done for alpha=40.0, beta=3.2
# calculation done for alpha=40.0, beta=3.2
# calculation done for alpha=40.0, beta=3.2
# calculation done for alpha=40.0, beta=3.6
# calculation done for alpha=40.0, beta=3.6
# calculation done for alpha=40.0, beta=3.6
# calculation done for alpha=40.0, beta=3.6
# calculation done for alpha=50.0, beta=0.0
# calculation done for alpha=50.0, beta=0.0
# calculation done for alpha=50.0, beta=0.0
# calculation done for alpha=50.0, beta=0.0
# calculation done for alpha=50.0, beta=0.4
# calculation done for alpha=50.0, beta=0.4
# calculation done for alpha=50.0, beta=0.4
# calculation done for alpha=50.0, beta=0.4
# calculation done for alpha=50.0, beta=0.8
# calculation done for alpha=50.0, beta=0.8
# calculation done for alpha=50.0, beta=0.8
# calculation done for alpha=50.0, beta=0.8
# calculation done for alpha=50.0, beta=1.2000000000000002
# calculation done for alpha=50.0, beta=1.2000000000000002
# calculation done for alpha=50.0, beta=1.2000000000000002
# calculation done for alpha=50.0, beta=1.2000000000000002
# calculation done for alpha=50.0, beta=1.6
# calculation done for alpha=50.0, beta=1.6
# calculation done for alpha=50.0, beta=1.6
# calculation done for alpha=50.0, beta=1.6
# calculation done for alpha=50.0, beta=2.0
# calculation done for alpha=50.0, beta=2.0
# calculation done for alpha=50.0, beta=2.0
# calculation done for alpha=50.0, beta=2.0
# calculation done for alpha=50.0, beta=2.4000000000000004
# calculation done for alpha=50.0, beta=2.4000000000000004
# calculation done for alpha=50.0, beta=2.4000000000000004
# calculation done for alpha=50.0, beta=2.4000000000000004
# calculation done for alpha=50.0, beta=2.8000000000000003
# calculation done for alpha=50.0, beta=2.8000000000000003
# calculation done for alpha=50.0, beta=2.8000000000000003
# calculation done for alpha=50.0, beta=2.8000000000000003
# calculation done for alpha=50.0, beta=3.2
# calculation done for alpha=50.0, beta=3.2
# calculation done for alpha=50.0, beta=3.2
# calculation done for alpha=50.0, beta=3.2
# calculation done for alpha=50.0, beta=3.6
# calculation done for alpha=50.0, beta=3.6
# calculation done for alpha=50.0, beta=3.6
# calculation done for alpha=50.0, beta=3.6
# calculation done for alpha=60.0, beta=0.0
# calculation done for alpha=60.0, beta=0.0
# calculation done for alpha=60.0, beta=0.0
# calculation done for alpha=60.0, beta=0.0
# calculation done for alpha=60.0, beta=0.4
# calculation done for alpha=60.0, beta=0.4
# calculation done for alpha=60.0, beta=0.4
# calculation done for alpha=60.0, beta=0.4
# calculation done for alpha=60.0, beta=0.8
# calculation done for alpha=60.0, beta=0.8
# calculation done for alpha=60.0, beta=0.8
# calculation done for alpha=60.0, beta=0.8
# calculation done for alpha=60.0, beta=1.2000000000000002
# calculation done for alpha=60.0, beta=1.2000000000000002
# calculation done for alpha=60.0, beta=1.2000000000000002
# calculation done for alpha=60.0, beta=1.2000000000000002
# calculation done for alpha=60.0, beta=1.6
# calculation done for alpha=60.0, beta=1.6
# calculation done for alpha=60.0, beta=1.6
# calculation done for alpha=60.0, beta=1.6
# calculation done for alpha=60.0, beta=2.0
# calculation done for alpha=60.0, beta=2.0
# calculation done for alpha=60.0, beta=2.0
# calculation done for alpha=60.0, beta=2.0
# calculation done for alpha=60.0, beta=2.4000000000000004
# calculation done for alpha=60.0, beta=2.4000000000000004
# calculation done for alpha=60.0, beta=2.4000000000000004
# calculation done for alpha=60.0, beta=2.4000000000000004
# calculation done for alpha=60.0, beta=2.8000000000000003
# calculation done for alpha=60.0, beta=2.8000000000000003
# calculation done for alpha=60.0, beta=2.8000000000000003
# calculation done for alpha=60.0, beta=2.8000000000000003
# calculation done for alpha=60.0, beta=3.2
# calculation done for alpha=60.0, beta=3.2
# calculation done for alpha=60.0, beta=3.2
# calculation done for alpha=60.0, beta=3.2
# calculation done for alpha=60.0, beta=3.6
# calculation done for alpha=60.0, beta=3.6
# calculation done for alpha=60.0, beta=3.6
# calculation done for alpha=60.0, beta=3.6
# calculation done for alpha=70.0, beta=0.0
# calculation done for alpha=70.0, beta=0.0
# calculation done for alpha=70.0, beta=0.0
# calculation done for alpha=70.0, beta=0.0
# calculation done for alpha=70.0, beta=0.4
# calculation done for alpha=70.0, beta=0.4
# calculation done for alpha=70.0, beta=0.4
# calculation done for alpha=70.0, beta=0.4
# calculation done for alpha=70.0, beta=0.8
# calculation done for alpha=70.0, beta=0.8
# calculation done for alpha=70.0, beta=0.8
# calculation done for alpha=70.0, beta=0.8
# calculation done for alpha=70.0, beta=1.2000000000000002
# calculation done for alpha=70.0, beta=1.2000000000000002
# calculation done for alpha=70.0, beta=1.2000000000000002
# calculation done for alpha=70.0, beta=1.2000000000000002
# calculation done for alpha=70.0, beta=1.6
# calculation done for alpha=70.0, beta=1.6
# calculation done for alpha=70.0, beta=1.6
# calculation done for alpha=70.0, beta=1.6
# calculation done for alpha=70.0, beta=2.0
# calculation done for alpha=70.0, beta=2.0
# calculation done for alpha=70.0, beta=2.0
# calculation done for alpha=70.0, beta=2.0
# calculation done for alpha=70.0, beta=2.4000000000000004
# calculation done for alpha=70.0, beta=2.4000000000000004
# calculation done for alpha=70.0, beta=2.4000000000000004
# calculation done for alpha=70.0, beta=2.4000000000000004
# calculation done for alpha=70.0, beta=2.8000000000000003
# calculation done for alpha=70.0, beta=2.8000000000000003
# calculation done for alpha=70.0, beta=2.8000000000000003
# calculation done for alpha=70.0, beta=2.8000000000000003
# calculation done for alpha=70.0, beta=3.2
# calculation done for alpha=70.0, beta=3.2
# calculation done for alpha=70.0, beta=3.2
# calculation done for alpha=70.0, beta=3.2
# calculation done for alpha=70.0, beta=3.6
# calculation done for alpha=70.0, beta=3.6
# calculation done for alpha=70.0, beta=3.6
# calculation done for alpha=70.0, beta=3.6
# calculation done for alpha=80.0, beta=0.0
# calculation done for alpha=80.0, beta=0.0
# calculation done for alpha=80.0, beta=0.0
# calculation done for alpha=80.0, beta=0.0
# calculation done for alpha=80.0, beta=0.4
# calculation done for alpha=80.0, beta=0.4
# calculation done for alpha=80.0, beta=0.4
# calculation done for alpha=80.0, beta=0.4
# calculation done for alpha=80.0, beta=0.8
# calculation done for alpha=80.0, beta=0.8
# calculation done for alpha=80.0, beta=0.8
# calculation done for alpha=80.0, beta=0.8
# calculation done for alpha=80.0, beta=1.2000000000000002
# calculation done for alpha=80.0, beta=1.2000000000000002
# calculation done for alpha=80.0, beta=1.2000000000000002
# calculation done for alpha=80.0, beta=1.2000000000000002
# calculation done for alpha=80.0, beta=1.6
# calculation done for alpha=80.0, beta=1.6
# calculation done for alpha=80.0, beta=1.6
# calculation done for alpha=80.0, beta=1.6
# calculation done for alpha=80.0, beta=2.0
# calculation done for alpha=80.0, beta=2.0
# calculation done for alpha=80.0, beta=2.0
# calculation done for alpha=80.0, beta=2.0
# calculation done for alpha=80.0, beta=2.4000000000000004
# calculation done for alpha=80.0, beta=2.4000000000000004
# calculation done for alpha=80.0, beta=2.4000000000000004
# calculation done for alpha=80.0, beta=2.4000000000000004
# calculation done for alpha=80.0, beta=2.8000000000000003
# calculation done for alpha=80.0, beta=2.8000000000000003
# calculation done for alpha=80.0, beta=2.8000000000000003
# calculation done for alpha=80.0, beta=2.8000000000000003
# calculation done for alpha=80.0, beta=3.2
# calculation done for alpha=80.0, beta=3.2
# calculation done for alpha=80.0, beta=3.2
# calculation done for alpha=80.0, beta=3.2
# calculation done for alpha=80.0, beta=3.6
# calculation done for alpha=80.0, beta=3.6
# calculation done for alpha=80.0, beta=3.6
# calculation done for alpha=80.0, beta=3.6
# calculation done for alpha=90.0, beta=0.0
# calculation done for alpha=90.0, beta=0.0
# calculation done for alpha=90.0, beta=0.0
# calculation done for alpha=90.0, beta=0.0
# calculation done for alpha=90.0, beta=0.4
# calculation done for alpha=90.0, beta=0.4
# calculation done for alpha=90.0, beta=0.4
# calculation done for alpha=90.0, beta=0.4
# calculation done for alpha=90.0, beta=0.8
# calculation done for alpha=90.0, beta=0.8
# calculation done for alpha=90.0, beta=0.8
# calculation done for alpha=90.0, beta=0.8
# calculation done for alpha=90.0, beta=1.2000000000000002
# calculation done for alpha=90.0, beta=1.2000000000000002
# calculation done for alpha=90.0, beta=1.2000000000000002
# calculation done for alpha=90.0, beta=1.2000000000000002
# calculation done for alpha=90.0, beta=1.6
# calculation done for alpha=90.0, beta=1.6
# calculation done for alpha=90.0, beta=1.6
# calculation done for alpha=90.0, beta=1.6
# calculation done for alpha=90.0, beta=2.0
# calculation done for alpha=90.0, beta=2.0
# calculation done for alpha=90.0, beta=2.0
# calculation done for alpha=90.0, beta=2.0
# calculation done for alpha=90.0, beta=2.4000000000000004
# calculation done for alpha=90.0, beta=2.4000000000000004
# calculation done for alpha=90.0, beta=2.4000000000000004
# calculation done for alpha=90.0, beta=2.4000000000000004
# calculation done for alpha=90.0, beta=2.8000000000000003
# calculation done for alpha=90.0, beta=2.8000000000000003
# calculation done for alpha=90.0, beta=2.8000000000000003
# calculation done for alpha=90.0, beta=2.8000000000000003
# calculation done for alpha=90.0, beta=3.2
# calculation done for alpha=90.0, beta=3.2
# calculation done for alpha=90.0, beta=3.2
# calculation done for alpha=90.0, beta=3.2
# calculation done for alpha=90.0, beta=3.6
# calculation done for alpha=90.0, beta=3.6
# calculation done for alpha=90.0, beta=3.6
# calculation done for alpha=90.0, beta=3.6

# %%
_result_Phis
# Out:
# array([[[556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736],
#         [556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736],
#         [556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736],
#         [556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736],
#         [556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736],
#         [556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736],
#         [556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736],
#         [556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736],
#         [556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736],
#         [556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736]],
#
#        [[556.24548736, 694.05405405, 642.        , 642.        ,
#          642.        , 513.6       , 188.82352941, 135.15789474,
#          104.3902439 ,  82.30769231],
#         [556.24548736, 694.05405405, 675.78947368, 642.        ,
#          642.        , 513.6       , 188.82352941, 135.15789474,
#          104.3902439 ,  82.30769231],
#         [556.24548736, 694.05405405, 694.05405405, 675.78947368,
#          642.        , 642.        , 197.53846154, 135.15789474,
#          104.3902439 ,  82.30769231],
#         [556.24548736, 694.05405405, 675.78947368, 675.78947368,
#          642.        , 642.        , 197.53846154, 147.5862069 ,
#          104.3902439 ,  82.30769231],
#         [556.24548736, 713.33333333, 675.78947368, 675.78947368,
#          642.        , 642.        , 197.53846154, 147.5862069 ,
#          104.3902439 ,  82.30769231],
#         [556.24548736, 713.33333333, 675.78947368, 675.78947368,
#          642.        , 642.        , 197.53846154, 147.5862069 ,
#          104.3902439 ,  82.30769231],
#         [556.24548736, 713.33333333, 713.33333333, 675.78947368,
#          642.        , 642.        , 197.53846154, 147.5862069 ,
#          104.3902439 ,  82.30769231],
#         [556.24548736, 713.33333333, 713.33333333, 675.78947368,
#          642.        , 642.        , 513.6       , 147.5862069 ,
#          104.3902439 ,  82.30769231],
#         [556.24548736, 713.33333333, 713.33333333, 675.78947368,
#          642.        , 642.        , 513.6       , 147.5862069 ,
#          104.3902439 ,  82.30769231],
#         [556.24548736, 713.33333333, 713.33333333, 675.78947368,
#          675.78947368, 642.        , 513.6       , 158.51851852,
#          104.3902439 ,  82.30769231]],
#
#        [[556.24548736, 484.52830189, 428.        , 442.75862069,
#          442.75862069, 315.73770492, 298.60465116, 217.62711864,
#          217.62711864, 197.53846154],
#         [556.24548736, 493.84615385, 458.57142857, 442.75862069,
#          442.75862069, 323.69747899, 298.60465116, 217.62711864,
#          217.62711864, 263.83561644],
#         [556.24548736, 493.84615385, 493.84615385, 458.57142857,
#          442.75862069, 442.75862069, 337.89473684, 217.62711864,
#          229.28571429, 263.83561644],
#         [556.24548736, 493.84615385, 458.57142857, 458.57142857,
#          442.75862069, 442.75862069, 337.89473684, 217.62711864,
#          229.28571429, 262.93515358],
#         [556.24548736, 611.42857143, 458.57142857, 458.57142857,
#          442.75862069, 442.75862069, 337.89473684, 217.62711864,
#          229.28571429, 263.83561644],
#         [556.24548736, 611.42857143, 458.57142857, 442.75862069,
#          442.75862069, 442.75862069, 337.89473684, 217.62711864,
#          229.28571429, 262.93515358],
#         [556.24548736, 611.42857143, 611.42857143, 442.75862069,
#          442.75862069, 442.75862069, 337.89473684, 217.62711864,
#          229.28571429, 262.93515358],
#         [556.24548736, 597.20930233, 611.42857143, 442.75862069,
#          435.25423729, 442.75862069, 288.        , 217.62711864,
#          229.28571429, 263.83561644],
#         [556.24548736, 597.20930233, 611.42857143, 442.75862069,
#          428.        , 442.75862069, 288.        , 229.28571429,
#          229.28571429, 263.83561644],
#         [556.24548736, 611.42857143, 611.42857143, 442.75862069,
#          458.57142857, 442.75862069, 288.        , 229.28571429,
#          229.28571429, 262.93515358]],
#
#        [[556.24548736, 389.09090909, 207.09677419, 145.90909091,
#           84.47368421,  38.44311377,  42.58706468,  41.96078431,
#           41.96078431,  41.96078431],
#         [556.24548736, 493.84615385, 389.09090909, 251.76470588,
#          125.88235294,  78.77300613,  81.52380952,  79.25925926,
#           79.25925926,  79.25925926],
#         [556.24548736, 428.        , 414.19354839, 356.66666667,
#          144.26966292, 102.72      ,  79.25925926,  79.25925926,
#           79.25925926,  79.25925926],
#         [556.24548736, 414.19354839, 389.09090909, 401.25      ,
#          186.08695652, 103.5483871 ,  79.25925926,  79.25925926,
#           79.25925926,  79.25925926],
#         [556.24548736, 675.78947368, 389.09090909, 401.25      ,
#          200.625     , 107.        ,  79.25925926,  79.25925926,
#           79.25925926,  79.25925926],
#         [556.24548736, 675.78947368, 389.09090909, 420.98360656,
#          225.26315789, 112.63157895,  79.25925926,  79.25925926,
#           79.25925926,  79.25925926],
#         [556.24548736, 675.78947368, 642.        , 420.98360656,
#          256.8       , 116.72727273,  79.25925926,  79.25925926,
#           79.25925926,  79.25925926],
#         [556.24548736, 675.78947368, 642.        , 420.98360656,
#          262.04081633, 121.13207547,  75.0877193 ,  79.25925926,
#           79.25925926,  79.25925926],
#         [556.24548736, 675.78947368, 642.        , 420.98360656,
#          267.5       , 124.66019417,  75.52941176,  79.25925926,
#           79.25925926,  79.25925926],
#         [556.24548736, 675.78947368, 642.        , 420.98360656,
#          356.66666667, 127.12871287,  75.52941176,  79.25925926,
#           79.25925926,  79.25925926]]])

# %% [markdown]
# # plot

# %%
# OPTIMUM= 742 # Nexullance_OPT [GBps]

# colors=['red', 'orangered', 'gold', 'yellowgreen']

# fig = plt.figure()
# ax = fig.add_subplot(projection='3d')
# for i, _alpha in enumerate(_alphas):
#     for j, _beta in enumerate(_betas):
#         for it in range(num_method_1):
#             ax.scatter(_alpha, _beta, _result_Phis[it,i,j]/OPTIMUM, marker='o', c = colors[it], label =f"{it} times")

# ax.set_xlabel('alpha')
# ax.set_ylabel('beta')
# ax.set_zlabel('achieved $\Phi$ (normalized to Nexullance_OPT)')

# ax.set_zlim([0,1])

# plt.legend()

# plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

OPTIMUM = 742.0  # Nexullance_OPT [GBps]
colors = ['red', 'orange', 'gold', 'yellowgreen']

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

legend_handles = []  # List to store legend handles
legend_labels = []   # List to store legend labels

for i, _alpha in enumerate(_alphas):
    for j, _beta in enumerate(_betas):
        for it in range(num_method_1):
            # Scatter plot
            ax.scatter(_alpha, _beta, _result_Phis[it, i, j] / OPTIMUM,
                       marker='o', c=colors[it])

# Create legend handles and labels for each color
for it, color in enumerate(colors):
    legend_handles.append(ax.scatter([], [], [], c=color, label=f"{it+1} times"))
    legend_labels.append(f"{it+1} times")

ax.set_xlabel('alpha')
ax.set_ylabel('beta')
ax.set_zlabel('achieved $\Phi$ (normalized to Nexullance_OPT)')
ax.set_zlim([0, 1])

# Plot legend with the handles and labels created
plt.legend(handles=legend_handles, labels=legend_labels)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
