# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../..')))
import matplotlib.pyplot as plt
import numpy as np
from Nexullance_IT import Nexullance_IT
from Nexullance_MP import Nexullance_MP
from topologies.DDF import DDFtopo
import globals as gl
import copy
from joblib import Parallel, delayed
# %matplotlib widget

# %% [markdown]
# # setup network, not yet using nexullance

# %%
config=(36, 5)
EPR=3
_network = DDFtopo(config[0], config[1])
Cap_remote = 10 #GBps
Cap_local = 10 #GBps
M_EPs = gl.generate_uniform_traffic_pattern(config[0], EPR) # an numpy matrix filled with ones
M_R = gl.convert_M_EPs_to_M_R(M_EPs, config[0], EPR)

# %%
ASP, _ = _network.calculate_all_shortest_paths()
ECMP_ASP = gl.ECMP(ASP)
remote_link_flows, local_link_flows = _network.distribute_M_EPs_on_weighted_paths(ECMP_ASP, EPR, M_EPs)
max_remote_link_load = np.max(remote_link_flows)/Cap_remote
max_local_link_load = np.max(local_link_flows)/Cap_local

# adapt the traffic scaling factor to 10x saturation
traffic_scaling = 10.0/max(max_local_link_load, max_remote_link_load)
M_EPs = traffic_scaling * M_EPs
M_R = gl.convert_M_EPs_to_M_R(M_EPs, config[0], EPR)
remote_link_flows, local_link_flows = _network.distribute_M_EPs_on_weighted_paths(ECMP_ASP, EPR, M_EPs)
max_remote_link_load = np.max(remote_link_flows)/Cap_remote
max_local_link_load = np.max(local_link_flows)/Cap_local

print("Max remote link load: ", max_remote_link_load)
print("Max local link load: ", max_local_link_load)
if max_remote_link_load > 1.0 or max_local_link_load > 1.0:
    print("network congestion may present")
    mu = max_local_link_load/max_remote_link_load
    if mu > 1.0:
        print(f"mu = {mu} > 1, max local link load is higher")
    else:
        print(f"mu = {mu} < 1, max remote link load is higher")
else:
    print("network is probably not congested")
print("network_total_throughput = ", gl.network_total_throughput(M_EPs, max_remote_link_load, max_local_link_load), "GBps")
# Out:
# Max remote link load:  10.000000000000007
# Max local link load:  5.150421179302045
# network congestion may present
# mu = 0.5150421179302042 < 1, max remote link load is higher
# network_total_throughput =  556.2454873646205 GBps

# %%
# apply simple ECMP_MP_APST4:
MP_APST4, _ = _network.calculate_all_paths_within_length(4)
nexu = Nexullance_MP(_network.nx_graph, MP_APST4, M_R, Cap_remote, 0, False)
nexu.init_model()
Lremote_NEXU_MP_MP_APST4, _ = nexu.solve()
OPTIMUM = gl.network_total_throughput(M_EPs, Lremote_NEXU_MP_MP_APST4, max_local_link_load)
print(f"OPTIMUM is:{OPTIMUM}")
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2411299
# Academic license 2411299 - for non-commercial use only - registered to zi___@ugent.be
# Set parameter Threads to value 1
# Optimal solution found
# OPTIMUM is:775.3166421207659

# %% [markdown]
# # start to sweep parameters

# %%
# initialize data
_alphas = np.array(list(range(0, 20, 2)), dtype=float)
_alphas[0]+=0.1
_betas = np.array(list(np.arange(0.0, 4.0, 0.4)), dtype=float)

num_method_1 = 10
_result_Phis = np.ndarray((num_method_1, len(_alphas), len(_betas)), dtype=float)*0 
# the first dimension corresponds to iterations

# %%
nexu_it = Nexullance_IT(_network.nx_graph, M_R, Cap_remote)

# %%
# Function to be executed in parallel
def parallel_method(alpha, beta):
    nexu_it_test = copy.deepcopy(nexu_it)
    def weighted_method(s: int, d: int, edge_attributes: dict):
        return method_1_weights(s, d, edge_attributes, alpha, beta)
    result_list, _ = nexu_it_test.optimize(num_method_1, 0, weighted_method, None, method_1_learning_rate= 0.1)
    return [gl.network_total_throughput(M_EPs, result_list[it], max_local_link_load) for it in range(num_method_1)]

# Function to calculate method_1_weights
def method_1_weights(s: int, d: int, edge_attributes: dict, alpha: float, beta: float):
    return alpha + edge_attributes['learning_load']**beta

# Parallel computation
results = Parallel(n_jobs=10)(
    delayed(parallel_method)(alpha, beta) for alpha in _alphas for beta in _betas
)

# Process the results
for i, _alpha in enumerate(_alphas):
    for j, _beta in enumerate(_betas):
        for it in range(num_method_1):
            _result_Phis[it, i, j] = results[i * len(_betas) + j][it]
            print(f"calculation done for alpha={_alpha}, beta={_beta}")
            #TODO: validate the matching of data
# Out:
# calculation done for alpha=0.1, beta=0.0
# calculation done for alpha=0.1, beta=0.0
# calculation done for alpha=0.1, beta=0.0
# calculation done for alpha=0.1, beta=0.0
# calculation done for alpha=0.1, beta=0.0
# calculation done for alpha=0.1, beta=0.0
# calculation done for alpha=0.1, beta=0.0
# calculation done for alpha=0.1, beta=0.0
# calculation done for alpha=0.1, beta=0.0
# calculation done for alpha=0.1, beta=0.0
# calculation done for alpha=0.1, beta=0.4
# calculation done for alpha=0.1, beta=0.4
# calculation done for alpha=0.1, beta=0.4
# calculation done for alpha=0.1, beta=0.4
# calculation done for alpha=0.1, beta=0.4
# calculation done for alpha=0.1, beta=0.4
# calculation done for alpha=0.1, beta=0.4
# calculation done for alpha=0.1, beta=0.4
# calculation done for alpha=0.1, beta=0.4
# calculation done for alpha=0.1, beta=0.4
# calculation done for alpha=0.1, beta=0.8
# calculation done for alpha=0.1, beta=0.8
# calculation done for alpha=0.1, beta=0.8
# calculation done for alpha=0.1, beta=0.8
# calculation done for alpha=0.1, beta=0.8
# calculation done for alpha=0.1, beta=0.8
# calculation done for alpha=0.1, beta=0.8
# calculation done for alpha=0.1, beta=0.8
# calculation done for alpha=0.1, beta=0.8
# calculation done for alpha=0.1, beta=0.8
# calculation done for alpha=0.1, beta=1.2000000000000002
# calculation done for alpha=0.1, beta=1.2000000000000002
# calculation done for alpha=0.1, beta=1.2000000000000002
# calculation done for alpha=0.1, beta=1.2000000000000002
# calculation done for alpha=0.1, beta=1.2000000000000002
# calculation done for alpha=0.1, beta=1.2000000000000002
# calculation done for alpha=0.1, beta=1.2000000000000002
# calculation done for alpha=0.1, beta=1.2000000000000002
# calculation done for alpha=0.1, beta=1.2000000000000002
# calculation done for alpha=0.1, beta=1.2000000000000002
# calculation done for alpha=0.1, beta=1.6
# calculation done for alpha=0.1, beta=1.6
# calculation done for alpha=0.1, beta=1.6
# calculation done for alpha=0.1, beta=1.6
# calculation done for alpha=0.1, beta=1.6
# calculation done for alpha=0.1, beta=1.6
# calculation done for alpha=0.1, beta=1.6
# calculation done for alpha=0.1, beta=1.6
# calculation done for alpha=0.1, beta=1.6
# calculation done for alpha=0.1, beta=1.6
# calculation done for alpha=0.1, beta=2.0
# calculation done for alpha=0.1, beta=2.0
# calculation done for alpha=0.1, beta=2.0
# calculation done for alpha=0.1, beta=2.0
# calculation done for alpha=0.1, beta=2.0
# calculation done for alpha=0.1, beta=2.0
# calculation done for alpha=0.1, beta=2.0
# calculation done for alpha=0.1, beta=2.0
# calculation done for alpha=0.1, beta=2.0
# calculation done for alpha=0.1, beta=2.0
# calculation done for alpha=0.1, beta=2.4000000000000004
# calculation done for alpha=0.1, beta=2.4000000000000004
# calculation done for alpha=0.1, beta=2.4000000000000004
# calculation done for alpha=0.1, beta=2.4000000000000004
# calculation done for alpha=0.1, beta=2.4000000000000004
# calculation done for alpha=0.1, beta=2.4000000000000004
# calculation done for alpha=0.1, beta=2.4000000000000004
# calculation done for alpha=0.1, beta=2.4000000000000004
# calculation done for alpha=0.1, beta=2.4000000000000004
# calculation done for alpha=0.1, beta=2.4000000000000004
# calculation done for alpha=0.1, beta=2.8000000000000003
# calculation done for alpha=0.1, beta=2.8000000000000003
# calculation done for alpha=0.1, beta=2.8000000000000003
# calculation done for alpha=0.1, beta=2.8000000000000003
# calculation done for alpha=0.1, beta=2.8000000000000003
# calculation done for alpha=0.1, beta=2.8000000000000003
# calculation done for alpha=0.1, beta=2.8000000000000003
# calculation done for alpha=0.1, beta=2.8000000000000003
# calculation done for alpha=0.1, beta=2.8000000000000003
# calculation done for alpha=0.1, beta=2.8000000000000003
# calculation done for alpha=0.1, beta=3.2
# calculation done for alpha=0.1, beta=3.2
# calculation done for alpha=0.1, beta=3.2
# calculation done for alpha=0.1, beta=3.2
# calculation done for alpha=0.1, beta=3.2
# calculation done for alpha=0.1, beta=3.2
# calculation done for alpha=0.1, beta=3.2
# calculation done for alpha=0.1, beta=3.2
# calculation done for alpha=0.1, beta=3.2
# calculation done for alpha=0.1, beta=3.2
# calculation done for alpha=0.1, beta=3.6
# calculation done for alpha=0.1, beta=3.6
# calculation done for alpha=0.1, beta=3.6
# calculation done for alpha=0.1, beta=3.6
# calculation done for alpha=0.1, beta=3.6
# calculation done for alpha=0.1, beta=3.6
# calculation done for alpha=0.1, beta=3.6
# calculation done for alpha=0.1, beta=3.6
# calculation done for alpha=0.1, beta=3.6
# calculation done for alpha=0.1, beta=3.6
# calculation done for alpha=2.0, beta=0.0
# calculation done for alpha=2.0, beta=0.0
# calculation done for alpha=2.0, beta=0.0
# calculation done for alpha=2.0, beta=0.0
# calculation done for alpha=2.0, beta=0.0
# calculation done for alpha=2.0, beta=0.0
# calculation done for alpha=2.0, beta=0.0
# calculation done for alpha=2.0, beta=0.0
# calculation done for alpha=2.0, beta=0.0
# calculation done for alpha=2.0, beta=0.0
# calculation done for alpha=2.0, beta=0.4
# calculation done for alpha=2.0, beta=0.4
# calculation done for alpha=2.0, beta=0.4
# calculation done for alpha=2.0, beta=0.4
# calculation done for alpha=2.0, beta=0.4
# calculation done for alpha=2.0, beta=0.4
# calculation done for alpha=2.0, beta=0.4
# calculation done for alpha=2.0, beta=0.4
# calculation done for alpha=2.0, beta=0.4
# calculation done for alpha=2.0, beta=0.4
# calculation done for alpha=2.0, beta=0.8
# calculation done for alpha=2.0, beta=0.8
# calculation done for alpha=2.0, beta=0.8
# calculation done for alpha=2.0, beta=0.8
# calculation done for alpha=2.0, beta=0.8
# calculation done for alpha=2.0, beta=0.8
# calculation done for alpha=2.0, beta=0.8
# calculation done for alpha=2.0, beta=0.8
# calculation done for alpha=2.0, beta=0.8
# calculation done for alpha=2.0, beta=0.8
# calculation done for alpha=2.0, beta=1.2000000000000002
# calculation done for alpha=2.0, beta=1.2000000000000002
# calculation done for alpha=2.0, beta=1.2000000000000002
# calculation done for alpha=2.0, beta=1.2000000000000002
# calculation done for alpha=2.0, beta=1.2000000000000002
# calculation done for alpha=2.0, beta=1.2000000000000002
# calculation done for alpha=2.0, beta=1.2000000000000002
# calculation done for alpha=2.0, beta=1.2000000000000002
# calculation done for alpha=2.0, beta=1.2000000000000002
# calculation done for alpha=2.0, beta=1.2000000000000002
# calculation done for alpha=2.0, beta=1.6
# calculation done for alpha=2.0, beta=1.6
# calculation done for alpha=2.0, beta=1.6
# calculation done for alpha=2.0, beta=1.6
# calculation done for alpha=2.0, beta=1.6
# calculation done for alpha=2.0, beta=1.6
# calculation done for alpha=2.0, beta=1.6
# calculation done for alpha=2.0, beta=1.6
# calculation done for alpha=2.0, beta=1.6
# calculation done for alpha=2.0, beta=1.6
# calculation done for alpha=2.0, beta=2.0
# calculation done for alpha=2.0, beta=2.0
# calculation done for alpha=2.0, beta=2.0
# calculation done for alpha=2.0, beta=2.0
# calculation done for alpha=2.0, beta=2.0
# calculation done for alpha=2.0, beta=2.0
# calculation done for alpha=2.0, beta=2.0
# calculation done for alpha=2.0, beta=2.0
# calculation done for alpha=2.0, beta=2.0
# calculation done for alpha=2.0, beta=2.0
# calculation done for alpha=2.0, beta=2.4000000000000004
# calculation done for alpha=2.0, beta=2.4000000000000004
# calculation done for alpha=2.0, beta=2.4000000000000004
# calculation done for alpha=2.0, beta=2.4000000000000004
# calculation done for alpha=2.0, beta=2.4000000000000004
# calculation done for alpha=2.0, beta=2.4000000000000004
# calculation done for alpha=2.0, beta=2.4000000000000004
# calculation done for alpha=2.0, beta=2.4000000000000004
# calculation done for alpha=2.0, beta=2.4000000000000004
# calculation done for alpha=2.0, beta=2.4000000000000004
# calculation done for alpha=2.0, beta=2.8000000000000003
# calculation done for alpha=2.0, beta=2.8000000000000003
# calculation done for alpha=2.0, beta=2.8000000000000003
# calculation done for alpha=2.0, beta=2.8000000000000003
# calculation done for alpha=2.0, beta=2.8000000000000003
# calculation done for alpha=2.0, beta=2.8000000000000003
# calculation done for alpha=2.0, beta=2.8000000000000003
# calculation done for alpha=2.0, beta=2.8000000000000003
# calculation done for alpha=2.0, beta=2.8000000000000003
# calculation done for alpha=2.0, beta=2.8000000000000003
# calculation done for alpha=2.0, beta=3.2
# calculation done for alpha=2.0, beta=3.2
# calculation done for alpha=2.0, beta=3.2
# calculation done for alpha=2.0, beta=3.2
# calculation done for alpha=2.0, beta=3.2
# calculation done for alpha=2.0, beta=3.2
# calculation done for alpha=2.0, beta=3.2
# calculation done for alpha=2.0, beta=3.2
# calculation done for alpha=2.0, beta=3.2
# calculation done for alpha=2.0, beta=3.2
# calculation done for alpha=2.0, beta=3.6
# calculation done for alpha=2.0, beta=3.6
# calculation done for alpha=2.0, beta=3.6
# calculation done for alpha=2.0, beta=3.6
# calculation done for alpha=2.0, beta=3.6
# calculation done for alpha=2.0, beta=3.6
# calculation done for alpha=2.0, beta=3.6
# calculation done for alpha=2.0, beta=3.6
# calculation done for alpha=2.0, beta=3.6
# calculation done for alpha=2.0, beta=3.6
# calculation done for alpha=4.0, beta=0.0
# calculation done for alpha=4.0, beta=0.0
# calculation done for alpha=4.0, beta=0.0
# calculation done for alpha=4.0, beta=0.0
# calculation done for alpha=4.0, beta=0.0
# calculation done for alpha=4.0, beta=0.0
# calculation done for alpha=4.0, beta=0.0
# calculation done for alpha=4.0, beta=0.0
# calculation done for alpha=4.0, beta=0.0
# calculation done for alpha=4.0, beta=0.0
# calculation done for alpha=4.0, beta=0.4
# calculation done for alpha=4.0, beta=0.4
# calculation done for alpha=4.0, beta=0.4
# calculation done for alpha=4.0, beta=0.4
# calculation done for alpha=4.0, beta=0.4
# calculation done for alpha=4.0, beta=0.4
# calculation done for alpha=4.0, beta=0.4
# calculation done for alpha=4.0, beta=0.4
# calculation done for alpha=4.0, beta=0.4
# calculation done for alpha=4.0, beta=0.4
# calculation done for alpha=4.0, beta=0.8
# calculation done for alpha=4.0, beta=0.8
# calculation done for alpha=4.0, beta=0.8
# calculation done for alpha=4.0, beta=0.8
# calculation done for alpha=4.0, beta=0.8
# calculation done for alpha=4.0, beta=0.8
# calculation done for alpha=4.0, beta=0.8
# calculation done for alpha=4.0, beta=0.8
# calculation done for alpha=4.0, beta=0.8
# calculation done for alpha=4.0, beta=0.8
# calculation done for alpha=4.0, beta=1.2000000000000002
# calculation done for alpha=4.0, beta=1.2000000000000002
# calculation done for alpha=4.0, beta=1.2000000000000002
# calculation done for alpha=4.0, beta=1.2000000000000002
# calculation done for alpha=4.0, beta=1.2000000000000002
# calculation done for alpha=4.0, beta=1.2000000000000002
# calculation done for alpha=4.0, beta=1.2000000000000002
# calculation done for alpha=4.0, beta=1.2000000000000002
# calculation done for alpha=4.0, beta=1.2000000000000002
# calculation done for alpha=4.0, beta=1.2000000000000002
# calculation done for alpha=4.0, beta=1.6
# calculation done for alpha=4.0, beta=1.6
# calculation done for alpha=4.0, beta=1.6
# calculation done for alpha=4.0, beta=1.6
# calculation done for alpha=4.0, beta=1.6
# calculation done for alpha=4.0, beta=1.6
# calculation done for alpha=4.0, beta=1.6
# calculation done for alpha=4.0, beta=1.6
# calculation done for alpha=4.0, beta=1.6
# calculation done for alpha=4.0, beta=1.6
# calculation done for alpha=4.0, beta=2.0
# calculation done for alpha=4.0, beta=2.0
# calculation done for alpha=4.0, beta=2.0
# calculation done for alpha=4.0, beta=2.0
# calculation done for alpha=4.0, beta=2.0
# calculation done for alpha=4.0, beta=2.0
# calculation done for alpha=4.0, beta=2.0
# calculation done for alpha=4.0, beta=2.0
# calculation done for alpha=4.0, beta=2.0
# calculation done for alpha=4.0, beta=2.0
# calculation done for alpha=4.0, beta=2.4000000000000004
# calculation done for alpha=4.0, beta=2.4000000000000004
# calculation done for alpha=4.0, beta=2.4000000000000004
# calculation done for alpha=4.0, beta=2.4000000000000004
# calculation done for alpha=4.0, beta=2.4000000000000004
# calculation done for alpha=4.0, beta=2.4000000000000004
# calculation done for alpha=4.0, beta=2.4000000000000004
# calculation done for alpha=4.0, beta=2.4000000000000004
# calculation done for alpha=4.0, beta=2.4000000000000004
# calculation done for alpha=4.0, beta=2.4000000000000004
# calculation done for alpha=4.0, beta=2.8000000000000003
# calculation done for alpha=4.0, beta=2.8000000000000003
# calculation done for alpha=4.0, beta=2.8000000000000003
# calculation done for alpha=4.0, beta=2.8000000000000003
# calculation done for alpha=4.0, beta=2.8000000000000003
# calculation done for alpha=4.0, beta=2.8000000000000003
# calculation done for alpha=4.0, beta=2.8000000000000003
# calculation done for alpha=4.0, beta=2.8000000000000003
# calculation done for alpha=4.0, beta=2.8000000000000003
# calculation done for alpha=4.0, beta=2.8000000000000003
# calculation done for alpha=4.0, beta=3.2
# calculation done for alpha=4.0, beta=3.2
# calculation done for alpha=4.0, beta=3.2
# calculation done for alpha=4.0, beta=3.2
# calculation done for alpha=4.0, beta=3.2
# calculation done for alpha=4.0, beta=3.2
# calculation done for alpha=4.0, beta=3.2
# calculation done for alpha=4.0, beta=3.2
# calculation done for alpha=4.0, beta=3.2
# calculation done for alpha=4.0, beta=3.2
# calculation done for alpha=4.0, beta=3.6
# calculation done for alpha=4.0, beta=3.6
# calculation done for alpha=4.0, beta=3.6
# calculation done for alpha=4.0, beta=3.6
# calculation done for alpha=4.0, beta=3.6
# calculation done for alpha=4.0, beta=3.6
# calculation done for alpha=4.0, beta=3.6
# calculation done for alpha=4.0, beta=3.6
# calculation done for alpha=4.0, beta=3.6
# calculation done for alpha=4.0, beta=3.6
# calculation done for alpha=6.0, beta=0.0
# calculation done for alpha=6.0, beta=0.0
# calculation done for alpha=6.0, beta=0.0
# calculation done for alpha=6.0, beta=0.0
# calculation done for alpha=6.0, beta=0.0
# calculation done for alpha=6.0, beta=0.0
# calculation done for alpha=6.0, beta=0.0
# calculation done for alpha=6.0, beta=0.0
# calculation done for alpha=6.0, beta=0.0
# calculation done for alpha=6.0, beta=0.0
# calculation done for alpha=6.0, beta=0.4
# calculation done for alpha=6.0, beta=0.4
# calculation done for alpha=6.0, beta=0.4
# calculation done for alpha=6.0, beta=0.4
# calculation done for alpha=6.0, beta=0.4
# calculation done for alpha=6.0, beta=0.4
# calculation done for alpha=6.0, beta=0.4
# calculation done for alpha=6.0, beta=0.4
# calculation done for alpha=6.0, beta=0.4
# calculation done for alpha=6.0, beta=0.4
# calculation done for alpha=6.0, beta=0.8
# calculation done for alpha=6.0, beta=0.8
# calculation done for alpha=6.0, beta=0.8
# calculation done for alpha=6.0, beta=0.8
# calculation done for alpha=6.0, beta=0.8
# calculation done for alpha=6.0, beta=0.8
# calculation done for alpha=6.0, beta=0.8
# calculation done for alpha=6.0, beta=0.8
# calculation done for alpha=6.0, beta=0.8
# calculation done for alpha=6.0, beta=0.8
# calculation done for alpha=6.0, beta=1.2000000000000002
# calculation done for alpha=6.0, beta=1.2000000000000002
# calculation done for alpha=6.0, beta=1.2000000000000002
# calculation done for alpha=6.0, beta=1.2000000000000002
# calculation done for alpha=6.0, beta=1.2000000000000002
# calculation done for alpha=6.0, beta=1.2000000000000002
# calculation done for alpha=6.0, beta=1.2000000000000002
# calculation done for alpha=6.0, beta=1.2000000000000002
# calculation done for alpha=6.0, beta=1.2000000000000002
# calculation done for alpha=6.0, beta=1.2000000000000002
# calculation done for alpha=6.0, beta=1.6
# calculation done for alpha=6.0, beta=1.6
# calculation done for alpha=6.0, beta=1.6
# calculation done for alpha=6.0, beta=1.6
# calculation done for alpha=6.0, beta=1.6
# calculation done for alpha=6.0, beta=1.6
# calculation done for alpha=6.0, beta=1.6
# calculation done for alpha=6.0, beta=1.6
# calculation done for alpha=6.0, beta=1.6
# calculation done for alpha=6.0, beta=1.6
# calculation done for alpha=6.0, beta=2.0
# calculation done for alpha=6.0, beta=2.0
# calculation done for alpha=6.0, beta=2.0
# calculation done for alpha=6.0, beta=2.0
# calculation done for alpha=6.0, beta=2.0
# calculation done for alpha=6.0, beta=2.0
# calculation done for alpha=6.0, beta=2.0
# calculation done for alpha=6.0, beta=2.0
# calculation done for alpha=6.0, beta=2.0
# calculation done for alpha=6.0, beta=2.0
# calculation done for alpha=6.0, beta=2.4000000000000004
# calculation done for alpha=6.0, beta=2.4000000000000004
# calculation done for alpha=6.0, beta=2.4000000000000004
# calculation done for alpha=6.0, beta=2.4000000000000004
# calculation done for alpha=6.0, beta=2.4000000000000004
# calculation done for alpha=6.0, beta=2.4000000000000004
# calculation done for alpha=6.0, beta=2.4000000000000004
# calculation done for alpha=6.0, beta=2.4000000000000004
# calculation done for alpha=6.0, beta=2.4000000000000004
# calculation done for alpha=6.0, beta=2.4000000000000004
# calculation done for alpha=6.0, beta=2.8000000000000003
# calculation done for alpha=6.0, beta=2.8000000000000003
# calculation done for alpha=6.0, beta=2.8000000000000003
# calculation done for alpha=6.0, beta=2.8000000000000003
# calculation done for alpha=6.0, beta=2.8000000000000003
# calculation done for alpha=6.0, beta=2.8000000000000003
# calculation done for alpha=6.0, beta=2.8000000000000003
# calculation done for alpha=6.0, beta=2.8000000000000003
# calculation done for alpha=6.0, beta=2.8000000000000003
# calculation done for alpha=6.0, beta=2.8000000000000003
# calculation done for alpha=6.0, beta=3.2
# calculation done for alpha=6.0, beta=3.2
# calculation done for alpha=6.0, beta=3.2
# calculation done for alpha=6.0, beta=3.2
# calculation done for alpha=6.0, beta=3.2
# calculation done for alpha=6.0, beta=3.2
# calculation done for alpha=6.0, beta=3.2
# calculation done for alpha=6.0, beta=3.2
# calculation done for alpha=6.0, beta=3.2
# calculation done for alpha=6.0, beta=3.2
# calculation done for alpha=6.0, beta=3.6
# calculation done for alpha=6.0, beta=3.6
# calculation done for alpha=6.0, beta=3.6
# calculation done for alpha=6.0, beta=3.6
# calculation done for alpha=6.0, beta=3.6
# calculation done for alpha=6.0, beta=3.6
# calculation done for alpha=6.0, beta=3.6
# calculation done for alpha=6.0, beta=3.6
# calculation done for alpha=6.0, beta=3.6
# calculation done for alpha=6.0, beta=3.6
# calculation done for alpha=8.0, beta=0.0
# calculation done for alpha=8.0, beta=0.0
# calculation done for alpha=8.0, beta=0.0
# calculation done for alpha=8.0, beta=0.0
# calculation done for alpha=8.0, beta=0.0
# calculation done for alpha=8.0, beta=0.0
# calculation done for alpha=8.0, beta=0.0
# calculation done for alpha=8.0, beta=0.0
# calculation done for alpha=8.0, beta=0.0
# calculation done for alpha=8.0, beta=0.0
# calculation done for alpha=8.0, beta=0.4
# calculation done for alpha=8.0, beta=0.4
# calculation done for alpha=8.0, beta=0.4
# calculation done for alpha=8.0, beta=0.4
# calculation done for alpha=8.0, beta=0.4
# calculation done for alpha=8.0, beta=0.4
# calculation done for alpha=8.0, beta=0.4
# calculation done for alpha=8.0, beta=0.4
# calculation done for alpha=8.0, beta=0.4
# calculation done for alpha=8.0, beta=0.4
# calculation done for alpha=8.0, beta=0.8
# calculation done for alpha=8.0, beta=0.8
# calculation done for alpha=8.0, beta=0.8
# calculation done for alpha=8.0, beta=0.8
# calculation done for alpha=8.0, beta=0.8
# calculation done for alpha=8.0, beta=0.8
# calculation done for alpha=8.0, beta=0.8
# calculation done for alpha=8.0, beta=0.8
# calculation done for alpha=8.0, beta=0.8
# calculation done for alpha=8.0, beta=0.8
# calculation done for alpha=8.0, beta=1.2000000000000002
# calculation done for alpha=8.0, beta=1.2000000000000002
# calculation done for alpha=8.0, beta=1.2000000000000002
# calculation done for alpha=8.0, beta=1.2000000000000002
# calculation done for alpha=8.0, beta=1.2000000000000002
# calculation done for alpha=8.0, beta=1.2000000000000002
# calculation done for alpha=8.0, beta=1.2000000000000002
# calculation done for alpha=8.0, beta=1.2000000000000002
# calculation done for alpha=8.0, beta=1.2000000000000002
# calculation done for alpha=8.0, beta=1.2000000000000002
# calculation done for alpha=8.0, beta=1.6
# calculation done for alpha=8.0, beta=1.6
# calculation done for alpha=8.0, beta=1.6
# calculation done for alpha=8.0, beta=1.6
# calculation done for alpha=8.0, beta=1.6
# calculation done for alpha=8.0, beta=1.6
# calculation done for alpha=8.0, beta=1.6
# calculation done for alpha=8.0, beta=1.6
# calculation done for alpha=8.0, beta=1.6
# calculation done for alpha=8.0, beta=1.6
# calculation done for alpha=8.0, beta=2.0
# calculation done for alpha=8.0, beta=2.0
# calculation done for alpha=8.0, beta=2.0
# calculation done for alpha=8.0, beta=2.0
# calculation done for alpha=8.0, beta=2.0
# calculation done for alpha=8.0, beta=2.0
# calculation done for alpha=8.0, beta=2.0
# calculation done for alpha=8.0, beta=2.0
# calculation done for alpha=8.0, beta=2.0
# calculation done for alpha=8.0, beta=2.0
# calculation done for alpha=8.0, beta=2.4000000000000004
# calculation done for alpha=8.0, beta=2.4000000000000004
# calculation done for alpha=8.0, beta=2.4000000000000004
# calculation done for alpha=8.0, beta=2.4000000000000004
# calculation done for alpha=8.0, beta=2.4000000000000004
# calculation done for alpha=8.0, beta=2.4000000000000004
# calculation done for alpha=8.0, beta=2.4000000000000004
# calculation done for alpha=8.0, beta=2.4000000000000004
# calculation done for alpha=8.0, beta=2.4000000000000004
# calculation done for alpha=8.0, beta=2.4000000000000004
# calculation done for alpha=8.0, beta=2.8000000000000003
# calculation done for alpha=8.0, beta=2.8000000000000003
# calculation done for alpha=8.0, beta=2.8000000000000003
# calculation done for alpha=8.0, beta=2.8000000000000003
# calculation done for alpha=8.0, beta=2.8000000000000003
# calculation done for alpha=8.0, beta=2.8000000000000003
# calculation done for alpha=8.0, beta=2.8000000000000003
# calculation done for alpha=8.0, beta=2.8000000000000003
# calculation done for alpha=8.0, beta=2.8000000000000003
# calculation done for alpha=8.0, beta=2.8000000000000003
# calculation done for alpha=8.0, beta=3.2
# calculation done for alpha=8.0, beta=3.2
# calculation done for alpha=8.0, beta=3.2
# calculation done for alpha=8.0, beta=3.2
# calculation done for alpha=8.0, beta=3.2
# calculation done for alpha=8.0, beta=3.2
# calculation done for alpha=8.0, beta=3.2
# calculation done for alpha=8.0, beta=3.2
# calculation done for alpha=8.0, beta=3.2
# calculation done for alpha=8.0, beta=3.2
# calculation done for alpha=8.0, beta=3.6
# calculation done for alpha=8.0, beta=3.6
# calculation done for alpha=8.0, beta=3.6
# calculation done for alpha=8.0, beta=3.6
# calculation done for alpha=8.0, beta=3.6
# calculation done for alpha=8.0, beta=3.6
# calculation done for alpha=8.0, beta=3.6
# calculation done for alpha=8.0, beta=3.6
# calculation done for alpha=8.0, beta=3.6
# calculation done for alpha=8.0, beta=3.6
# calculation done for alpha=10.0, beta=0.0
# calculation done for alpha=10.0, beta=0.0
# calculation done for alpha=10.0, beta=0.0
# calculation done for alpha=10.0, beta=0.0
# calculation done for alpha=10.0, beta=0.0
# calculation done for alpha=10.0, beta=0.0
# calculation done for alpha=10.0, beta=0.0
# calculation done for alpha=10.0, beta=0.0
# calculation done for alpha=10.0, beta=0.0
# calculation done for alpha=10.0, beta=0.0
# calculation done for alpha=10.0, beta=0.4
# calculation done for alpha=10.0, beta=0.4
# calculation done for alpha=10.0, beta=0.4
# calculation done for alpha=10.0, beta=0.4
# calculation done for alpha=10.0, beta=0.4
# calculation done for alpha=10.0, beta=0.4
# calculation done for alpha=10.0, beta=0.4
# calculation done for alpha=10.0, beta=0.4
# calculation done for alpha=10.0, beta=0.4
# calculation done for alpha=10.0, beta=0.4
# calculation done for alpha=10.0, beta=0.8
# calculation done for alpha=10.0, beta=0.8
# calculation done for alpha=10.0, beta=0.8
# calculation done for alpha=10.0, beta=0.8
# calculation done for alpha=10.0, beta=0.8
# calculation done for alpha=10.0, beta=0.8
# calculation done for alpha=10.0, beta=0.8
# calculation done for alpha=10.0, beta=0.8
# calculation done for alpha=10.0, beta=0.8
# calculation done for alpha=10.0, beta=0.8
# calculation done for alpha=10.0, beta=1.2000000000000002
# calculation done for alpha=10.0, beta=1.2000000000000002
# calculation done for alpha=10.0, beta=1.2000000000000002
# calculation done for alpha=10.0, beta=1.2000000000000002
# calculation done for alpha=10.0, beta=1.2000000000000002
# calculation done for alpha=10.0, beta=1.2000000000000002
# calculation done for alpha=10.0, beta=1.2000000000000002
# calculation done for alpha=10.0, beta=1.2000000000000002
# calculation done for alpha=10.0, beta=1.2000000000000002
# calculation done for alpha=10.0, beta=1.2000000000000002
# calculation done for alpha=10.0, beta=1.6
# calculation done for alpha=10.0, beta=1.6
# calculation done for alpha=10.0, beta=1.6
# calculation done for alpha=10.0, beta=1.6
# calculation done for alpha=10.0, beta=1.6
# calculation done for alpha=10.0, beta=1.6
# calculation done for alpha=10.0, beta=1.6
# calculation done for alpha=10.0, beta=1.6
# calculation done for alpha=10.0, beta=1.6
# calculation done for alpha=10.0, beta=1.6
# calculation done for alpha=10.0, beta=2.0
# calculation done for alpha=10.0, beta=2.0
# calculation done for alpha=10.0, beta=2.0
# calculation done for alpha=10.0, beta=2.0
# calculation done for alpha=10.0, beta=2.0
# calculation done for alpha=10.0, beta=2.0
# calculation done for alpha=10.0, beta=2.0
# calculation done for alpha=10.0, beta=2.0
# calculation done for alpha=10.0, beta=2.0
# calculation done for alpha=10.0, beta=2.0
# calculation done for alpha=10.0, beta=2.4000000000000004
# calculation done for alpha=10.0, beta=2.4000000000000004
# calculation done for alpha=10.0, beta=2.4000000000000004
# calculation done for alpha=10.0, beta=2.4000000000000004
# calculation done for alpha=10.0, beta=2.4000000000000004
# calculation done for alpha=10.0, beta=2.4000000000000004
# calculation done for alpha=10.0, beta=2.4000000000000004
# calculation done for alpha=10.0, beta=2.4000000000000004
# calculation done for alpha=10.0, beta=2.4000000000000004
# calculation done for alpha=10.0, beta=2.4000000000000004
# calculation done for alpha=10.0, beta=2.8000000000000003
# calculation done for alpha=10.0, beta=2.8000000000000003
# calculation done for alpha=10.0, beta=2.8000000000000003
# calculation done for alpha=10.0, beta=2.8000000000000003
# calculation done for alpha=10.0, beta=2.8000000000000003
# calculation done for alpha=10.0, beta=2.8000000000000003
# calculation done for alpha=10.0, beta=2.8000000000000003
# calculation done for alpha=10.0, beta=2.8000000000000003
# calculation done for alpha=10.0, beta=2.8000000000000003
# calculation done for alpha=10.0, beta=2.8000000000000003
# calculation done for alpha=10.0, beta=3.2
# calculation done for alpha=10.0, beta=3.2
# calculation done for alpha=10.0, beta=3.2
# calculation done for alpha=10.0, beta=3.2
# calculation done for alpha=10.0, beta=3.2
# calculation done for alpha=10.0, beta=3.2
# calculation done for alpha=10.0, beta=3.2
# calculation done for alpha=10.0, beta=3.2
# calculation done for alpha=10.0, beta=3.2
# calculation done for alpha=10.0, beta=3.2
# calculation done for alpha=10.0, beta=3.6
# calculation done for alpha=10.0, beta=3.6
# calculation done for alpha=10.0, beta=3.6
# calculation done for alpha=10.0, beta=3.6
# calculation done for alpha=10.0, beta=3.6
# calculation done for alpha=10.0, beta=3.6
# calculation done for alpha=10.0, beta=3.6
# calculation done for alpha=10.0, beta=3.6
# calculation done for alpha=10.0, beta=3.6
# calculation done for alpha=10.0, beta=3.6
# calculation done for alpha=12.0, beta=0.0
# calculation done for alpha=12.0, beta=0.0
# calculation done for alpha=12.0, beta=0.0
# calculation done for alpha=12.0, beta=0.0
# calculation done for alpha=12.0, beta=0.0
# calculation done for alpha=12.0, beta=0.0
# calculation done for alpha=12.0, beta=0.0
# calculation done for alpha=12.0, beta=0.0
# calculation done for alpha=12.0, beta=0.0
# calculation done for alpha=12.0, beta=0.0
# calculation done for alpha=12.0, beta=0.4
# calculation done for alpha=12.0, beta=0.4
# calculation done for alpha=12.0, beta=0.4
# calculation done for alpha=12.0, beta=0.4
# calculation done for alpha=12.0, beta=0.4
# calculation done for alpha=12.0, beta=0.4
# calculation done for alpha=12.0, beta=0.4
# calculation done for alpha=12.0, beta=0.4
# calculation done for alpha=12.0, beta=0.4
# calculation done for alpha=12.0, beta=0.4
# calculation done for alpha=12.0, beta=0.8
# calculation done for alpha=12.0, beta=0.8
# calculation done for alpha=12.0, beta=0.8
# calculation done for alpha=12.0, beta=0.8
# calculation done for alpha=12.0, beta=0.8
# calculation done for alpha=12.0, beta=0.8
# calculation done for alpha=12.0, beta=0.8
# calculation done for alpha=12.0, beta=0.8
# calculation done for alpha=12.0, beta=0.8
# calculation done for alpha=12.0, beta=0.8
# calculation done for alpha=12.0, beta=1.2000000000000002
# calculation done for alpha=12.0, beta=1.2000000000000002
# calculation done for alpha=12.0, beta=1.2000000000000002
# calculation done for alpha=12.0, beta=1.2000000000000002
# calculation done for alpha=12.0, beta=1.2000000000000002
# calculation done for alpha=12.0, beta=1.2000000000000002
# calculation done for alpha=12.0, beta=1.2000000000000002
# calculation done for alpha=12.0, beta=1.2000000000000002
# calculation done for alpha=12.0, beta=1.2000000000000002
# calculation done for alpha=12.0, beta=1.2000000000000002
# calculation done for alpha=12.0, beta=1.6
# calculation done for alpha=12.0, beta=1.6
# calculation done for alpha=12.0, beta=1.6
# calculation done for alpha=12.0, beta=1.6
# calculation done for alpha=12.0, beta=1.6
# calculation done for alpha=12.0, beta=1.6
# calculation done for alpha=12.0, beta=1.6
# calculation done for alpha=12.0, beta=1.6
# calculation done for alpha=12.0, beta=1.6
# calculation done for alpha=12.0, beta=1.6
# calculation done for alpha=12.0, beta=2.0
# calculation done for alpha=12.0, beta=2.0
# calculation done for alpha=12.0, beta=2.0
# calculation done for alpha=12.0, beta=2.0
# calculation done for alpha=12.0, beta=2.0
# calculation done for alpha=12.0, beta=2.0
# calculation done for alpha=12.0, beta=2.0
# calculation done for alpha=12.0, beta=2.0
# calculation done for alpha=12.0, beta=2.0
# calculation done for alpha=12.0, beta=2.0
# calculation done for alpha=12.0, beta=2.4000000000000004
# calculation done for alpha=12.0, beta=2.4000000000000004
# calculation done for alpha=12.0, beta=2.4000000000000004
# calculation done for alpha=12.0, beta=2.4000000000000004
# calculation done for alpha=12.0, beta=2.4000000000000004
# calculation done for alpha=12.0, beta=2.4000000000000004
# calculation done for alpha=12.0, beta=2.4000000000000004
# calculation done for alpha=12.0, beta=2.4000000000000004
# calculation done for alpha=12.0, beta=2.4000000000000004
# calculation done for alpha=12.0, beta=2.4000000000000004
# calculation done for alpha=12.0, beta=2.8000000000000003
# calculation done for alpha=12.0, beta=2.8000000000000003
# calculation done for alpha=12.0, beta=2.8000000000000003
# calculation done for alpha=12.0, beta=2.8000000000000003
# calculation done for alpha=12.0, beta=2.8000000000000003
# calculation done for alpha=12.0, beta=2.8000000000000003
# calculation done for alpha=12.0, beta=2.8000000000000003
# calculation done for alpha=12.0, beta=2.8000000000000003
# calculation done for alpha=12.0, beta=2.8000000000000003
# calculation done for alpha=12.0, beta=2.8000000000000003
# calculation done for alpha=12.0, beta=3.2
# calculation done for alpha=12.0, beta=3.2
# calculation done for alpha=12.0, beta=3.2
# calculation done for alpha=12.0, beta=3.2
# calculation done for alpha=12.0, beta=3.2
# calculation done for alpha=12.0, beta=3.2
# calculation done for alpha=12.0, beta=3.2
# calculation done for alpha=12.0, beta=3.2
# calculation done for alpha=12.0, beta=3.2
# calculation done for alpha=12.0, beta=3.2
# calculation done for alpha=12.0, beta=3.6
# calculation done for alpha=12.0, beta=3.6
# calculation done for alpha=12.0, beta=3.6
# calculation done for alpha=12.0, beta=3.6
# calculation done for alpha=12.0, beta=3.6
# calculation done for alpha=12.0, beta=3.6
# calculation done for alpha=12.0, beta=3.6
# calculation done for alpha=12.0, beta=3.6
# calculation done for alpha=12.0, beta=3.6
# calculation done for alpha=12.0, beta=3.6
# calculation done for alpha=14.0, beta=0.0
# calculation done for alpha=14.0, beta=0.0
# calculation done for alpha=14.0, beta=0.0
# calculation done for alpha=14.0, beta=0.0
# calculation done for alpha=14.0, beta=0.0
# calculation done for alpha=14.0, beta=0.0
# calculation done for alpha=14.0, beta=0.0
# calculation done for alpha=14.0, beta=0.0
# calculation done for alpha=14.0, beta=0.0
# calculation done for alpha=14.0, beta=0.0
# calculation done for alpha=14.0, beta=0.4
# calculation done for alpha=14.0, beta=0.4
# calculation done for alpha=14.0, beta=0.4
# calculation done for alpha=14.0, beta=0.4
# calculation done for alpha=14.0, beta=0.4
# calculation done for alpha=14.0, beta=0.4
# calculation done for alpha=14.0, beta=0.4
# calculation done for alpha=14.0, beta=0.4
# calculation done for alpha=14.0, beta=0.4
# calculation done for alpha=14.0, beta=0.4
# calculation done for alpha=14.0, beta=0.8
# calculation done for alpha=14.0, beta=0.8
# calculation done for alpha=14.0, beta=0.8
# calculation done for alpha=14.0, beta=0.8
# calculation done for alpha=14.0, beta=0.8
# calculation done for alpha=14.0, beta=0.8
# calculation done for alpha=14.0, beta=0.8
# calculation done for alpha=14.0, beta=0.8
# calculation done for alpha=14.0, beta=0.8
# calculation done for alpha=14.0, beta=0.8
# calculation done for alpha=14.0, beta=1.2000000000000002
# calculation done for alpha=14.0, beta=1.2000000000000002
# calculation done for alpha=14.0, beta=1.2000000000000002
# calculation done for alpha=14.0, beta=1.2000000000000002
# calculation done for alpha=14.0, beta=1.2000000000000002
# calculation done for alpha=14.0, beta=1.2000000000000002
# calculation done for alpha=14.0, beta=1.2000000000000002
# calculation done for alpha=14.0, beta=1.2000000000000002
# calculation done for alpha=14.0, beta=1.2000000000000002
# calculation done for alpha=14.0, beta=1.2000000000000002
# calculation done for alpha=14.0, beta=1.6
# calculation done for alpha=14.0, beta=1.6
# calculation done for alpha=14.0, beta=1.6
# calculation done for alpha=14.0, beta=1.6
# calculation done for alpha=14.0, beta=1.6
# calculation done for alpha=14.0, beta=1.6
# calculation done for alpha=14.0, beta=1.6
# calculation done for alpha=14.0, beta=1.6
# calculation done for alpha=14.0, beta=1.6
# calculation done for alpha=14.0, beta=1.6
# calculation done for alpha=14.0, beta=2.0
# calculation done for alpha=14.0, beta=2.0
# calculation done for alpha=14.0, beta=2.0
# calculation done for alpha=14.0, beta=2.0
# calculation done for alpha=14.0, beta=2.0
# calculation done for alpha=14.0, beta=2.0
# calculation done for alpha=14.0, beta=2.0
# calculation done for alpha=14.0, beta=2.0
# calculation done for alpha=14.0, beta=2.0
# calculation done for alpha=14.0, beta=2.0
# calculation done for alpha=14.0, beta=2.4000000000000004
# calculation done for alpha=14.0, beta=2.4000000000000004
# calculation done for alpha=14.0, beta=2.4000000000000004
# calculation done for alpha=14.0, beta=2.4000000000000004
# calculation done for alpha=14.0, beta=2.4000000000000004
# calculation done for alpha=14.0, beta=2.4000000000000004
# calculation done for alpha=14.0, beta=2.4000000000000004
# calculation done for alpha=14.0, beta=2.4000000000000004
# calculation done for alpha=14.0, beta=2.4000000000000004
# calculation done for alpha=14.0, beta=2.4000000000000004
# calculation done for alpha=14.0, beta=2.8000000000000003
# calculation done for alpha=14.0, beta=2.8000000000000003
# calculation done for alpha=14.0, beta=2.8000000000000003
# calculation done for alpha=14.0, beta=2.8000000000000003
# calculation done for alpha=14.0, beta=2.8000000000000003
# calculation done for alpha=14.0, beta=2.8000000000000003
# calculation done for alpha=14.0, beta=2.8000000000000003
# calculation done for alpha=14.0, beta=2.8000000000000003
# calculation done for alpha=14.0, beta=2.8000000000000003
# calculation done for alpha=14.0, beta=2.8000000000000003
# calculation done for alpha=14.0, beta=3.2
# calculation done for alpha=14.0, beta=3.2
# calculation done for alpha=14.0, beta=3.2
# calculation done for alpha=14.0, beta=3.2
# calculation done for alpha=14.0, beta=3.2
# calculation done for alpha=14.0, beta=3.2
# calculation done for alpha=14.0, beta=3.2
# calculation done for alpha=14.0, beta=3.2
# calculation done for alpha=14.0, beta=3.2
# calculation done for alpha=14.0, beta=3.2
# calculation done for alpha=14.0, beta=3.6
# calculation done for alpha=14.0, beta=3.6
# calculation done for alpha=14.0, beta=3.6
# calculation done for alpha=14.0, beta=3.6
# calculation done for alpha=14.0, beta=3.6
# calculation done for alpha=14.0, beta=3.6
# calculation done for alpha=14.0, beta=3.6
# calculation done for alpha=14.0, beta=3.6
# calculation done for alpha=14.0, beta=3.6
# calculation done for alpha=14.0, beta=3.6
# calculation done for alpha=16.0, beta=0.0
# calculation done for alpha=16.0, beta=0.0
# calculation done for alpha=16.0, beta=0.0
# calculation done for alpha=16.0, beta=0.0
# calculation done for alpha=16.0, beta=0.0
# calculation done for alpha=16.0, beta=0.0
# calculation done for alpha=16.0, beta=0.0
# calculation done for alpha=16.0, beta=0.0
# calculation done for alpha=16.0, beta=0.0
# calculation done for alpha=16.0, beta=0.0
# calculation done for alpha=16.0, beta=0.4
# calculation done for alpha=16.0, beta=0.4
# calculation done for alpha=16.0, beta=0.4
# calculation done for alpha=16.0, beta=0.4
# calculation done for alpha=16.0, beta=0.4
# calculation done for alpha=16.0, beta=0.4
# calculation done for alpha=16.0, beta=0.4
# calculation done for alpha=16.0, beta=0.4
# calculation done for alpha=16.0, beta=0.4
# calculation done for alpha=16.0, beta=0.4
# calculation done for alpha=16.0, beta=0.8
# calculation done for alpha=16.0, beta=0.8
# calculation done for alpha=16.0, beta=0.8
# calculation done for alpha=16.0, beta=0.8
# calculation done for alpha=16.0, beta=0.8
# calculation done for alpha=16.0, beta=0.8
# calculation done for alpha=16.0, beta=0.8
# calculation done for alpha=16.0, beta=0.8
# calculation done for alpha=16.0, beta=0.8
# calculation done for alpha=16.0, beta=0.8
# calculation done for alpha=16.0, beta=1.2000000000000002
# calculation done for alpha=16.0, beta=1.2000000000000002
# calculation done for alpha=16.0, beta=1.2000000000000002
# calculation done for alpha=16.0, beta=1.2000000000000002
# calculation done for alpha=16.0, beta=1.2000000000000002
# calculation done for alpha=16.0, beta=1.2000000000000002
# calculation done for alpha=16.0, beta=1.2000000000000002
# calculation done for alpha=16.0, beta=1.2000000000000002
# calculation done for alpha=16.0, beta=1.2000000000000002
# calculation done for alpha=16.0, beta=1.2000000000000002
# calculation done for alpha=16.0, beta=1.6
# calculation done for alpha=16.0, beta=1.6
# calculation done for alpha=16.0, beta=1.6
# calculation done for alpha=16.0, beta=1.6
# calculation done for alpha=16.0, beta=1.6
# calculation done for alpha=16.0, beta=1.6
# calculation done for alpha=16.0, beta=1.6
# calculation done for alpha=16.0, beta=1.6
# calculation done for alpha=16.0, beta=1.6
# calculation done for alpha=16.0, beta=1.6
# calculation done for alpha=16.0, beta=2.0
# calculation done for alpha=16.0, beta=2.0
# calculation done for alpha=16.0, beta=2.0
# calculation done for alpha=16.0, beta=2.0
# calculation done for alpha=16.0, beta=2.0
# calculation done for alpha=16.0, beta=2.0
# calculation done for alpha=16.0, beta=2.0
# calculation done for alpha=16.0, beta=2.0
# calculation done for alpha=16.0, beta=2.0
# calculation done for alpha=16.0, beta=2.0
# calculation done for alpha=16.0, beta=2.4000000000000004
# calculation done for alpha=16.0, beta=2.4000000000000004
# calculation done for alpha=16.0, beta=2.4000000000000004
# calculation done for alpha=16.0, beta=2.4000000000000004
# calculation done for alpha=16.0, beta=2.4000000000000004
# calculation done for alpha=16.0, beta=2.4000000000000004
# calculation done for alpha=16.0, beta=2.4000000000000004
# calculation done for alpha=16.0, beta=2.4000000000000004
# calculation done for alpha=16.0, beta=2.4000000000000004
# calculation done for alpha=16.0, beta=2.4000000000000004
# calculation done for alpha=16.0, beta=2.8000000000000003
# calculation done for alpha=16.0, beta=2.8000000000000003
# calculation done for alpha=16.0, beta=2.8000000000000003
# calculation done for alpha=16.0, beta=2.8000000000000003
# calculation done for alpha=16.0, beta=2.8000000000000003
# calculation done for alpha=16.0, beta=2.8000000000000003
# calculation done for alpha=16.0, beta=2.8000000000000003
# calculation done for alpha=16.0, beta=2.8000000000000003
# calculation done for alpha=16.0, beta=2.8000000000000003
# calculation done for alpha=16.0, beta=2.8000000000000003
# calculation done for alpha=16.0, beta=3.2
# calculation done for alpha=16.0, beta=3.2
# calculation done for alpha=16.0, beta=3.2
# calculation done for alpha=16.0, beta=3.2
# calculation done for alpha=16.0, beta=3.2
# calculation done for alpha=16.0, beta=3.2
# calculation done for alpha=16.0, beta=3.2
# calculation done for alpha=16.0, beta=3.2
# calculation done for alpha=16.0, beta=3.2
# calculation done for alpha=16.0, beta=3.2
# calculation done for alpha=16.0, beta=3.6
# calculation done for alpha=16.0, beta=3.6
# calculation done for alpha=16.0, beta=3.6
# calculation done for alpha=16.0, beta=3.6
# calculation done for alpha=16.0, beta=3.6
# calculation done for alpha=16.0, beta=3.6
# calculation done for alpha=16.0, beta=3.6
# calculation done for alpha=16.0, beta=3.6
# calculation done for alpha=16.0, beta=3.6
# calculation done for alpha=16.0, beta=3.6
# calculation done for alpha=18.0, beta=0.0
# calculation done for alpha=18.0, beta=0.0
# calculation done for alpha=18.0, beta=0.0
# calculation done for alpha=18.0, beta=0.0
# calculation done for alpha=18.0, beta=0.0
# calculation done for alpha=18.0, beta=0.0
# calculation done for alpha=18.0, beta=0.0
# calculation done for alpha=18.0, beta=0.0
# calculation done for alpha=18.0, beta=0.0
# calculation done for alpha=18.0, beta=0.0
# calculation done for alpha=18.0, beta=0.4
# calculation done for alpha=18.0, beta=0.4
# calculation done for alpha=18.0, beta=0.4
# calculation done for alpha=18.0, beta=0.4
# calculation done for alpha=18.0, beta=0.4
# calculation done for alpha=18.0, beta=0.4
# calculation done for alpha=18.0, beta=0.4
# calculation done for alpha=18.0, beta=0.4
# calculation done for alpha=18.0, beta=0.4
# calculation done for alpha=18.0, beta=0.4
# calculation done for alpha=18.0, beta=0.8
# calculation done for alpha=18.0, beta=0.8
# calculation done for alpha=18.0, beta=0.8
# calculation done for alpha=18.0, beta=0.8
# calculation done for alpha=18.0, beta=0.8
# calculation done for alpha=18.0, beta=0.8
# calculation done for alpha=18.0, beta=0.8
# calculation done for alpha=18.0, beta=0.8
# calculation done for alpha=18.0, beta=0.8
# calculation done for alpha=18.0, beta=0.8
# calculation done for alpha=18.0, beta=1.2000000000000002
# calculation done for alpha=18.0, beta=1.2000000000000002
# calculation done for alpha=18.0, beta=1.2000000000000002
# calculation done for alpha=18.0, beta=1.2000000000000002
# calculation done for alpha=18.0, beta=1.2000000000000002
# calculation done for alpha=18.0, beta=1.2000000000000002
# calculation done for alpha=18.0, beta=1.2000000000000002
# calculation done for alpha=18.0, beta=1.2000000000000002
# calculation done for alpha=18.0, beta=1.2000000000000002
# calculation done for alpha=18.0, beta=1.2000000000000002
# calculation done for alpha=18.0, beta=1.6
# calculation done for alpha=18.0, beta=1.6
# calculation done for alpha=18.0, beta=1.6
# calculation done for alpha=18.0, beta=1.6
# calculation done for alpha=18.0, beta=1.6
# calculation done for alpha=18.0, beta=1.6
# calculation done for alpha=18.0, beta=1.6
# calculation done for alpha=18.0, beta=1.6
# calculation done for alpha=18.0, beta=1.6
# calculation done for alpha=18.0, beta=1.6
# calculation done for alpha=18.0, beta=2.0
# calculation done for alpha=18.0, beta=2.0
# calculation done for alpha=18.0, beta=2.0
# calculation done for alpha=18.0, beta=2.0
# calculation done for alpha=18.0, beta=2.0
# calculation done for alpha=18.0, beta=2.0
# calculation done for alpha=18.0, beta=2.0
# calculation done for alpha=18.0, beta=2.0
# calculation done for alpha=18.0, beta=2.0
# calculation done for alpha=18.0, beta=2.0
# calculation done for alpha=18.0, beta=2.4000000000000004
# calculation done for alpha=18.0, beta=2.4000000000000004
# calculation done for alpha=18.0, beta=2.4000000000000004
# calculation done for alpha=18.0, beta=2.4000000000000004
# calculation done for alpha=18.0, beta=2.4000000000000004
# calculation done for alpha=18.0, beta=2.4000000000000004
# calculation done for alpha=18.0, beta=2.4000000000000004
# calculation done for alpha=18.0, beta=2.4000000000000004
# calculation done for alpha=18.0, beta=2.4000000000000004
# calculation done for alpha=18.0, beta=2.4000000000000004
# calculation done for alpha=18.0, beta=2.8000000000000003
# calculation done for alpha=18.0, beta=2.8000000000000003
# calculation done for alpha=18.0, beta=2.8000000000000003
# calculation done for alpha=18.0, beta=2.8000000000000003
# calculation done for alpha=18.0, beta=2.8000000000000003
# calculation done for alpha=18.0, beta=2.8000000000000003
# calculation done for alpha=18.0, beta=2.8000000000000003
# calculation done for alpha=18.0, beta=2.8000000000000003
# calculation done for alpha=18.0, beta=2.8000000000000003
# calculation done for alpha=18.0, beta=2.8000000000000003
# calculation done for alpha=18.0, beta=3.2
# calculation done for alpha=18.0, beta=3.2
# calculation done for alpha=18.0, beta=3.2
# calculation done for alpha=18.0, beta=3.2
# calculation done for alpha=18.0, beta=3.2
# calculation done for alpha=18.0, beta=3.2
# calculation done for alpha=18.0, beta=3.2
# calculation done for alpha=18.0, beta=3.2
# calculation done for alpha=18.0, beta=3.2
# calculation done for alpha=18.0, beta=3.2
# calculation done for alpha=18.0, beta=3.6
# calculation done for alpha=18.0, beta=3.6
# calculation done for alpha=18.0, beta=3.6
# calculation done for alpha=18.0, beta=3.6
# calculation done for alpha=18.0, beta=3.6
# calculation done for alpha=18.0, beta=3.6
# calculation done for alpha=18.0, beta=3.6
# calculation done for alpha=18.0, beta=3.6
# calculation done for alpha=18.0, beta=3.6
# calculation done for alpha=18.0, beta=3.6

# %%
_result_Phis
# Out:
# array([[[556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736],
#         [556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736],
#         [556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736],
#         [556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736],
#         [556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736],
#         [556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736],
#         [556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736],
#         [556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736],
#         [556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736],
#         [556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736, 556.24548736, 556.24548736,
#          556.24548736, 556.24548736]],
#
#        [[556.24548736, 642.        , 642.        , 642.        ,
#          210.49180328, 164.61538462, 105.24590164,  79.7515528 ,
#           78.29268293,  77.81818182],
#         [556.24548736, 642.        , 642.        , 642.        ,
#          558.26086957, 191.64179104, 116.72727273,  80.25      ,
#           78.29268293,  77.81818182],
#         [556.24548736, 642.        , 642.        , 642.        ,
#          642.        , 207.09677419, 132.37113402,  82.30769231,
#           78.77300613,  78.29268293],
#         [556.24548736, 642.        , 642.        , 642.        ,
#          642.        , 214.        , 142.66666667,  83.37662338,
#           78.77300613,  78.29268293],
#         [556.24548736, 642.        , 642.        , 642.        ,
#          642.        , 458.57142857, 152.85714286,  89.16666667,
#           78.29268293,  78.29268293],
#         [556.24548736, 642.        , 642.        , 642.        ,
#          642.        , 493.84615385, 164.61538462,  93.04347826,
#           78.29268293,  78.29268293],
#         [556.24548736, 642.        , 642.        , 642.        ,
#          642.        , 558.26086957, 175.89041096,  95.82089552,
#           78.29268293,  78.29268293],
#         [556.24548736, 642.        , 642.        , 642.        ,
#          642.        , 583.63636364, 191.64179104, 103.5483871 ,
#           78.29268293,  78.29268293],
#         [556.24548736, 642.        , 642.        , 642.        ,
#          642.        ,
#           28.98419865,  23.73382625],
#         [556.24548736, 475.55555556, 458.57142857, 256.8       ,
#           86.75675676,  40.125     ,  30.71770335,  56.31578947,
#           39.38650307,  30.64439141],
#         [556.24548736, 475.55555556, 458.57142857, 442.75862069,
#           72.54237288,  55.58441558,  37.43440233,  18.63570392,
#           29.04977376,  32.92307692],
#         [556.24548736, 475.55555556, 458.57142857, 475.55555556,
#           75.97633136,  53.72384937,  43.08724832,  26.97478992,
#           26.25766871,  27.43589744],
#         [556.24548736, 475.55555556, 458.57142857, 475.55555556,
#           79.25925926,  47.20588235,  38.44311377,  28.98419865,
#           46.02150538,  18.47482014],
#         [556.24548736, 475.55555556, 458.57142857, 428.        ,
#          145.90909091,  72.13483146,  40.63291139,  33.09278351,
#           21.79966044,  35.17808219],
#         [556.24548736, 475.55555556, 458.57142857, 428.        ,
#          178.33333333,  37.10982659,  25.17647059,  35.96638655,
#           35.66666667,  35.17808219],
#         [556.24548736, 475.55555556, 458.57142857, 428.        ,
#          414.19354839,  75.0877193 ,  31.47058824,  54.87179487,
#           26.36550308,  45.69395018],
#         [556.24548736, 475.55555556, 458.57142857, 428.        ,
#          414.19354839,  67.93650794,  28.40707965,  26.41975309,
#           26.58385093,  21.36439268],
#         [556.24548736, 475.55555556, 458.57142857, 428.        ,
#          401.25      ,  53.5       ,  27.49464668,  43.97260274,
#           33.4375    ,  30.64439141]]])

# %% [markdown]
# # plot

# %%
colors = ['red', 'orange', 'gold', 'yellow', 'green', 'cyan', 'blue', 'indigo', 'violet', 'magenta']


fig = plt.figure()
ax = fig.add_subplot(projection='3d')

legend_handles = []  # List to store legend handles
legend_labels = []   # List to store legend labels

for i, _alpha in enumerate(_alphas):
    for j, _beta in enumerate(_betas):
        for it in range(num_method_1):
            # Scatter plot
            ax.scatter(_alpha, _beta, _result_Phis[it, i, j] / OPTIMUM,
                       marker='o', c=colors[it])

# Create legend handles and labels for each color
for it, color in enumerate(colors):
    legend_handles.append(ax.scatter([], [], [], c=color, label=f"{it+1} times"))
    legend_labels.append(f"{it+1} repetitions")

ax.set_xlabel('alpha')
ax.set_ylabel('beta')
ax.set_zlabel('achieved $\Phi$ (normalized to Nexullance_OPT)')
ax.set_zlim([0, 1])
ax.set_title('DDF uniform traffic Nexullance_IT step1')

# Plot legend with the handles and labels created
plt.legend(handles=legend_handles, labels=legend_labels)
plt.show()
# Out:
# <>:24: SyntaxWarning: invalid escape sequence '\P'
# <>:24: SyntaxWarning: invalid escape sequence '\P'
# /tmp/ipykernel_2293762/1310472215.py:24: SyntaxWarning: invalid escape sequence '\P'
#   ax.set_zlabel('achieved $\Phi$ (normalized to Nexullance_OPT)')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.max(_result_Phis)/ OPTIMUM
# Out:
# 0.8280487804878048

# %%
arg = np.argmax(_result_Phis)
arg_rep = arg//100
arg_alpha = (arg%100)//10
arg_beta = arg%10

print("The optimal representation is: ", arg_rep)
print("The optimal alpha is: ", _alphas[arg_alpha])
print("The optimal beta is: ", _betas[arg_beta])
# Out:
# The optimal representation is:  1
# The optimal alpha is:  0.1
# The optimal beta is:  0.4
